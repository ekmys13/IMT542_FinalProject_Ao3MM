# %% [markdown]
# # Visualizations: First 10 Fanworks
# This notebook contains a set of draft data visualizations with minimal data from the first 10 fanworks in the Candela Obscura fanworks list. These are the draft visualizations that illustrate what can be done with the metadata json structure.

# %%
import pandas as pd
import plotly.express as px

# %%
# import json

# %%
# convert json to dataframe

# %%
# let's briefly strategize on what kinds of visualizations I want
# primarily counts / bar charts

# which relationship categories are most represented?
# which characters are most represented?
# which archive warnings are most represented?
# does word count have any impact on kudos or comments?
# does chapter count have any impact on kudos or comments?
# how many fics have been published over time?
