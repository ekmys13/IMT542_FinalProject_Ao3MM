# %% [markdown]
# # Draft notebook for figuring out how to scrape ao3 fics for metadata using Beautiful Soup

# %%
import pandas as pd
from bs4 import BeautifulSoup
import lxml

# %% [markdown]
# ## Basic tutorial with one webpage link

# %%
# code from tutorial: https://www.geeksforgeeks.org/python/beautifulsoup-scraping-link-from-html/

# import necessary libraries
from bs4 import BeautifulSoup
import requests
import re

# %%
# function to extract html document from given url
def getHTMLdocument(url):

    # request for HTML document of given url
    response = requests.get(url)

    # response will be provided in JSON format
    return response.text

# %%
# assign required credentials
# assign URL
url_to_scrape = "https://archiveofourown.org/works/80156821"

# %%
# create document
html_document = getHTMLdocument(url_to_scrape)

# %%
# create soup object
soup = BeautifulSoup(html_document, 'html.parser')

# %%
# find all the anchor tags with "href"
# attribute starting with "https://"
for link in soup.find_all('a',
                          attrs={'href': re.compile("^https://")}):
    # display the actual urls
    print(link.get('href'))
# Out:
# https://www.otwstatus.org
# https://github.com/otwcode/otwarchive/commits/v0.9.479.2
# https://www.gnu.org/licenses/old-licenses/gpl-2.0.html
# https://transformativeworks.org/

# %%
print(soup)

# %% [markdown]
# ## Attempting tutorial above with whole Candela Obscura fandom page

# %% [markdown]
# Note - didn't work the way I thought it would; I want it to pull all links associated with a particular tag; not sure how to do that yet

# %%
# let's try with like...the whole Candela Obscura fandom page
htmldocument1 = getHTMLdocument("https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works")

# %%
# create soup object
soup1 = BeautifulSoup(htmldocument1, 'html.parser')

# %%
# find all the anchor tags with "href"
# attribute starting with "https://"
for link in soup1.find_all('a',
                          attrs={'href': re.compile("^https://")}):
    # display the actual urls
    print(link.get('href'))
# Out:
# https://archiveofourown.org/cdn-cgi/content?id=5yIwl6YojqEgeoBOVIvQ061.mKc9ufQcO08fwJV0bc4-1780168350.665304-1.0.1.1-n49QuDzYZlsn4KIRt_Xt5dt0SY0ozn.iJgUlWiMKsOE
# https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&utm_campaign=archiveofourown.org
# https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&utm_campaign=archiveofourown.org
# https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&utm_campaign=archiveofourown.org
# https://developers.cloudflare.com/support/troubleshooting/http-status-codes/cloudflare-5xx-errors/error-525/
# https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_525&utm_campaign=archiveofourown.org

# %%
print(soup1.head)
# Out:
# <head>
# <title>archiveofourown.org | 525: SSL handshake failed</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/main.css" id="cf_styles-css" rel="stylesheet"/>
# </head>

# %% [markdown]
# ## Figuring out how to get metadata off one webpage

# %%
# get list of tags
# from: https://stackoverflow.com/questions/36108621/get-all-html-tags-with-beautiful-soup
print([tag.name for tag in soup.find_all()])
# Out:
# ['html', 'head', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'meta', 'title', 'link', 'link', 'link', 'link', 'link', 'link', 'script', 'meta', 'meta', 'body', 'div', 'ul', 'li', 'a', 'noscript', 'p', 'header', 'h1', 'a', 'span', 'img', 'div', 'p', 'a', 'div', 'form', 'input', 'dl', 'dt', 'label', 'dd', 'input', 'dt', 'label', 'dd', 'input', 'p', 'label', 'input', 'input', 'ul', 'li', 'a', 'li', 'a', 'nav', 'ul', 'li', 'a', 'ul', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'ul', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'form', 'fieldset', 'p', 'label', 'input', 'span', 'span', 'input', 'div', 'div', 'div', 'div', 'ul', 'li', 'a', 'li', 'a', 'div', 'h3', 'ul', 'li', 'a', 'li', 'a', 'li', 'noscript', 'h4',
# ...

# %%
# So...I think I need to figure out which tags correspond to the information I want
# so how do I do that...

# %%
soup4 = BeautifulSoup("<h2 id='message'>Hello, Tutorialspoint!</h2>",'html.parser')

tag = soup4.h2
string = str(tag.string)
print (string)
# Out:
# Hello, Tutorialspoint!

# %%
tag = soup1.html
print (tag.name)
# Out:
# html

# %%
soup3 = BeautifulSoup('<b class="boldest">TutorialsPoint</b>', 'lxml')
tag = soup3.html
tag.name = "strong"
print (tag)
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 soup3 = BeautifulSoup('<b class="boldest">TutorialsPoint</b>', 'lxml')
#       2 tag = soup3.html
#       3 tag.name = "strong"
#       4 print (tag)
#
# File ~/PycharmProjects/IMT542_FinalProject_Stelter/.venv/lib/python3.14/site-packages/bs4/__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
# ...

# %%
html = '''
<p>The quick, <b>brown fox</b> jumps over a lazy dog.</p>
'''
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "lxml")
print (soup.prettify())

# %%
french = "<p>Il a dit <<Sacré bleu!>></p>"
soup2 = BeautifulSoup(french, 'html.parser')
print ("minimal: ")
print(soup.prettify(formatter="minimal"))
print ("html: ")
print(soup.prettify(formatter="html"))
print ("None: ")
print(soup.prettify(formatter=None))

# %%
# trying to understand how the prettify stuff works
print(soup.prettify(formatter="html"))

# %%
print(soup.prettify(formatter="minimal"))
