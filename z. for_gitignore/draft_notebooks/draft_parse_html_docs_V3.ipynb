# %% [markdown]
# # Parse HTML Docs
# This notebook contains functions that:
# 1) Retrieves a list of fanwork links from a text file created with the functions in get_fanwork_links.ipynb
# 2) For each fanwork link, creates a BeautifulSoup object, parses the resulting html document, and extracts desired metadata about each fanwork
# 3) Saves the extracted metadata in a json structure

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

## TODO - remove once you've tested selenium
import requests

from bs4 import BeautifulSoup
import re
import json

# %% [markdown]
# # Retrieve fanworks list from text file

# %%
def get_fanwork_links(filepath):
    """Takes in a txt file of pagination links and returns a list."""
    fanwork_links = open(filepath).readlines()
    for i in range(len(fanwork_links)):
        fanwork_links[i] = fanwork_links[i].replace("\n","")
    return fanwork_links

# %% [markdown]
# # Create soup objects

# %%
def get_fanwork_html(url):
    driver = webdriver.Firefox()
    driver.get(url)

    # detect TOS agreement
    agreement_class_present = len(driver.find_elements(By.CLASS_NAME, value='agreement')) > 0
    print("TOS agreement section is present: ", str(agreement_class_present))

    # if agreement class is present, find TOS agreement checkboxes / submit button
    if agreement_class_present:
        wait = WebDriverWait(driver, 10)
        tos_agree = wait.until(EC.element_to_be_clickable((By.ID, 'tos_agree')))

        # click checkboxes + accept TOS
        actions = ActionChains(driver)
        actions.move_to_element(tos_agree).perform()
        actions.click(tos_agree).perform()

        data_processing_agree = wait.until(EC.element_to_be_clickable((By.ID, 'data_processing_agree')))
        actions.move_to_element(data_processing_agree).perform()
        actions.click(data_processing_agree).perform()

        accept_tos_button = wait.until(EC.element_to_be_clickable((By.ID, 'accept_tos')))
        actions.move_to_element(accept_tos_button).perform()
        actions.click(accept_tos_button).perform()

    else:
        pass

    # detect adult content warning
    accept_adult_content_present = len(driver.find_elements(By.LINK_TEXT, 'Yes, Continue')) > 0
    print("Adult content warning is present: ", str(accept_adult_content_present))

    if accept_adult_content_present:
        wait = WebDriverWait(driver, 15)
        accept_adult_content_button = wait.until(EC.element_to_be_clickable((By.LINK_TEXT, 'Yes, Continue')))

        # click link + accept adult content warning
        actions = ActionChains(driver)
        actions.move_to_element(accept_adult_content_button).perform()
        actions.click(accept_adult_content_button).perform()

    else:
        pass

    # return page source / html doc
    driver.implicitly_wait(10) # seconds

    # get OuterHTML from 'work meta group'
    work_meta_group = driver.find_element(By.CLASS_NAME, 'wrapper')
    outer_html = work_meta_group.get_attribute('outerHTML')

    return outer_html

# %%
## TODO - delete once you've tested the other one
def get_html_doc_fanworks(url):
    """Takes in the url for any given Ao3 fanwork and returns an html document of that page."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
def get_soup(html):
    soup = BeautifulSoup(html, features='html.parser')
    return soup

# %%
def get_all_dt(soup):
    """Takes in BeautifulSoup object from Ao3 fanwork and returns a list of all 'dt' elements of the html document. 'dt' elements represent the metadata categories present for the fanwork."""
    all_dt = soup.find_all('dt')
    # all_dt = list(all_dt)
    return all_dt

# %%
def update_all_dt(dt_list):
    dt_dict = {
        '<dt><label for="user_session_login_small">Username or email:</label></dt>':'user_session_login',
        '<dt><label for="user_session_password_small">Password:</label></dt>':'user_session_password',
        '<dt class="rating tags">':'Rating',
        '<dt class="warning tags">':'Archive Warning',
        '<dt class="category tags">':'Categories',
        '<dt class="fandom tags">':'Fandoms',
        '<dt class="relationship tags">':'Relationships',
        '<dt class="character tags">':'Characters',
        '<dt class="freeform tags">':'Additional Tags',
        '<dt class="language">':'Language',
        '<dt class="stats">':'Stats',
        '<dt class="published">':'Date Published',
        '<dt class="status">':'Date Updated',
        '<dt class="words">':'Word Count',
        '<dt class="chapters">':'Chapters',
        '<dt class="comments">':'Comments',
        '<dt class="kudos">':'Kudos',
        '<dt class="bookmarks">':'Bookmarks',
        '<dt class="hits">':'Hits',
        '<dt class="landmark">Note:</dt>':'note',
        '<dt><label for="comment_name_for_211688701">Guest name</label></dt>':'guest_commenter_name',
        '<dt><label for="comment_email_for_211688701">Guest email</label></dt>':'guest_commenter_email'
    }

    for i in range(len(dt_list)):
        dt_list[i] = str(dt_list[i])

    for key in dt_dict.keys():
        for i in range(len(dt_list)):
            key_string = str(key)
            if key_string in dt_list[i]:
                dt_list[i] = dt_dict[key]
            else:
                continue
    return dt_list

# %%
def get_all_dd(soup):
    """Takes in BeautifulSoup object from Aoe fanwork and returns a list of all 'dd' elements of the html document. 'dd' elements represent the metadata values present in the fanwork."""
    all_dd = soup.find_all('dd')
    # all_dd = list(all_dd)

    # convert dd_list items to strings
    for i in range(len(all_dd)):
        all_dd[i] = str(all_dd[i])

    return all_dd

# %% [markdown]
# # Parse html docs and clean metadata

# %% [markdown]
# ## strip_dd

# %%
def strip_dd(dd_list):
    text_to_strip = ['\n',
                 '<ul class="commas">',
                 '<li>','</li>',
                 '</ul>',
                 '<a class="tag" href="','</a>',
                 '<dd class="rating tags">',
                 '/tags/Not%20Rated/works">',
                 '/tags/General%20Audiences/works">',
                 '/tags/Teen%20And%20Up%20Audiences/works">',
                 '/tags/Mature/works">',
                 '/tags/Explicit/works">',
                 '<dd class="warning tags">',
                 '/tags/No%20Archive%20Warnings%20Apply/works">',
                 '/tags/Graphic%20Depictions%20Of%20Violence/works">',
                 '/tags/Choose%20Not%20To%20Use%20Archive%20Warnings/works">',
                 '/tags/Major%20Character%20Death/works">',
                 '/tags/Rape*s*Non-Con/works">',
                 '/tags/Underage%20Sex/works">',
                 '<dd class="category tags">',
                 '/tags/Gen/works">',
                 '/tags/F*s*F/works">',
                 '/tags/F*s*M/works">F/M',
                 '/tags/M*s*M/works">M/M',
                 '/tags/Multi/works">Multi',
                 '/tags/Other/works">Other',
                 '</dd>',
                 '<dd class="language" lang="en">',
                 '<!-- end of cache -->',
                 '<dd class="stats">',
                 '<dl class="stats">',
                 '<dt class="published">',
                 '</dt><dd class="published">',
                 '<dt class="status">',
                 '</dt><dd class="status">',
                 '<dt class="words">',
                 '</dt><dd class="words">',
                 '<dt class="chapters">',
                 '</dt><dd class="chapters">',
                 '<dt class="comments">',
                 '</dt><dd class="comments">',
                 '<dt class="kudos">',
                 '</dt><dd class="kudos">',
                 '<dt class="bookmarks">',
                 '</dt><dd class="bookmarks">',
                 'bookmarks">',
                 '<a href="/',
                 '<dt class="hits">',
                 '</dt><dd class="hits">',
                 '</dl>',
                 '<dd class="instructions comment_form">',
                 '<dd><input id="',
                 '" name="comment[name]" type="text"/><script>',
                 '/<![CDATA[var ',
                 ' = new LiveValidation',
                 ', { wait: 500, onlyOnBlur: false }',
                 '.add(Validate.Presence, {"failureMessage":"Please enter your name.","validMessage":""})',
                 ';//]]>',
                 '</script>',
                 '<input id="',
                 '" name="comment[email]"',
                 ' type="text"/>',
                 '<script>',
                 '.add(Validate.Presence, {"failureMessage":"Please enter your email address.","validMessage":""})',
                 '<dd><input autocomplete="on" ',
                 'id="user_session_login_small" '
                 ]
    for item in text_to_strip:
        for i in range(len(dd_list)):
            if item in dd_list[i]:
                dd_list[i] = dd_list[i].replace(item, "")
            else:
                continue
    return dd_list

# %% [markdown]
# ## cleanup_fandom_tags

# %%
def cleanup_fandom_tags(dd_list):
    for i in range(len(dd_list)):
        if '<dd class="fandom tags">' in dd_list[i]:
            dd_list[i] = dd_list[i].replace('&amp;','&')
            dd_list[i] = dd_list[i].replace('*a*','&')
            dd_list[i] = dd_list[i].replace('%20','')
            dd_list[i] = dd_list[i].replace('<dd class="fandom tags">','')

            dd_list[i] = dd_list[i].split('/tags')

            pattern = re.compile(r"(?<=>)(?!.*>).*")
            for index in range(len(dd_list[i])):
                match = re.search(pattern, dd_list[i][index])
                if match:
                    dd_list[i][index] = match.group(0)
                else:
                    dd_list[i][index] = dd_list[i][index]

        else:
            continue
    return dd_list

# %% [markdown]
# ## cleanup_relationship_tags

# %%
def cleanup_relationship_tags(dd_list):
    for i in range(len(dd_list)):
        if '<dd class="relationship tags">' in dd_list[i]:
            dd_list[i] = dd_list[i].replace('&amp;','&')
            dd_list[i] = dd_list[i].replace('*a*','&')
            dd_list[i] = dd_list[i].replace('%20','')
            dd_list[i] = dd_list[i].replace('<dd class="relationship tags">','')

            dd_list[i] = dd_list[i].split('/tags')

            pattern = re.compile(r"(?<=>)(?!.*>).*")
            for index in range(len(dd_list[i])):
                match = re.search(pattern, dd_list[i][index])
                if match:
                    dd_list[i][index] = match.group(0)
                else:
                    dd_list[i][index] = dd_list[i][index]

        else:
            continue
    return dd_list

# %% [markdown]
# ## cleanup_character_tags

# %%
def cleanup_character_tags(dd_list):
    for i in range(len(dd_list)):
        if '<dd class="character tags">' in dd_list[i]:
            dd_list[i] = dd_list[i].replace('&amp;','&')
            dd_list[i] = dd_list[i].replace('*a*','&')
            dd_list[i] = dd_list[i].replace('%20','')
            dd_list[i] = dd_list[i].replace('<dd class="character tags">','')

            dd_list[i] = dd_list[i].split('/tags')

            pattern = re.compile(r"(?<=>)(?!.*>).*")
            for index in range(len(dd_list[i])):
                match = re.search(pattern, dd_list[i][index])
                if match:
                    dd_list[i][index] = match.group(0)
                else:
                    dd_list[i][index] = dd_list[i][index]

        else:
            continue
    return dd_list

# %% [markdown]
# ## cleanup_additional_tags

# %%
def cleanup_additional_tags(dd_list):
    for i in range(len(dd_list)):
        if '<dd class="freeform tags">' in dd_list[i]:
            dd_list[i] = dd_list[i].replace('&amp;','&')
            dd_list[i] = dd_list[i].replace('*a*','&')
            dd_list[i] = dd_list[i].replace('%20','')
            dd_list[i] = dd_list[i].replace('<dd class="freeform tags">','')

            dd_list[i] = dd_list[i].split('/tags')

            pattern = re.compile(r"(?<=>)(?!.*>).*")
            for index in range(len(dd_list[i])):
                match = re.search(pattern, dd_list[i][index])
                if match:
                    dd_list[i][index] = match.group(0)
                else:
                    dd_list[i][index] = dd_list[i][index]

        else:
            continue
    return dd_list

# %% [markdown]
# # Retrieve Metadata

# %%
def get_rating(dt_list, dd_list):
    # find ratings index
    if 'Rating' in dt_list:
        index = dt_list.index('Rating')
        rating = dd_list[index]
        return rating

    else:
        rating = 'Unknown'
        return rating

# %%
def get_warnings(dt_list, dd_list):
    # find warning index
    if 'Archive Warning' in dt_list:
        index = dt_list.index('Archive Warning')
        warning = dd_list[index]
        return warning
    else:
        warning = 'No warnings listed'
        return warning

# %%
def get_category(dt_list, dd_list):
    # find category index
    if 'Categories' in dt_list:
        index = dt_list.index('Categories')
        category = dd_list[index]
        return category
    else:
        category = 'Unknown'
        return category

# %%
def get_language(dt_list, dd_list):
    """Uses language index found in find_language_index to get language metadata value for an Ao3 work."""
    if 'Language' in dt_list:
        index = dt_list.index("Language")
        language_str = dd_list[index]
        language_str = language_str.strip()
        return language_str
    else:
        language_str = 'Unknown'
        return language_str

# %%
def get_fandom(dt_list, dd_list):
    # find fandom index
    if 'Fandoms' in dt_list:
        index = dt_list.index("Fandoms")
        fandoms = dd_list[index]
        return fandoms
    else:
        fandoms = 'No fandoms listed'
        return fandoms

# %%
def get_relationships(dt_list, dd_list):
    # find relationship index
    if 'Relationships' in dt_list:
        index = dt_list.index("Relationships")
        relationships = dd_list[index]
        return relationships
    else:
        relationships = 'No relationships listed'
        return relationships

# %%
def get_characters(dt_list, dd_list):
    # find relationship index
    if 'Characters' in dt_list:
        index = dt_list.index('Characters')
        characters = dd_list[index]
        return characters
    else:
        characters = 'No characters listed'
        return characters

# %%
def get_additional_tags(dt_list, dd_list):
    # find additional tags index
    if 'Additional Tags' in dt_list:
        index = dt_list.index("Additional Tags")
        additional_tags = dd_list[index]
        return additional_tags
    else:
        additional_tags = 'No additional tags'
        return additional_tags

# %%
def is_series(dt_list):
    for i in range(len(dt_list)):
        current_string = dt_list[i]
        if 'Series' in current_string:
            is_part_of_series = True
            return is_part_of_series
        else:
            is_part_of_series = False
            return is_part_of_series

# %%
def get_date_published(dt_list, dd_list):
    # find date published index
    if 'Date Published' in dt_list:
        index = dt_list.index('Date Published')
        date_published = dd_list[index]
        date_published = date_published.split('>')
        date_published = date_published[1]
        return date_published

    else:
        date_published = 'Unknown'
        return date_published

# %%
def get_date_updated(dt_list, dd_list):
    # find date updated index
    if 'Date Updated' in dt_list:
        index = dt_list.index("Date Updated")
        date_updated = dd_list[index]
        date_updated = date_updated.split('>')
        date_updated = date_updated[1]
        return date_updated
    elif 'Date Published' in dt_list:
        index = dt_list.index('Date Published')
        date_updated = dd_list[index]
        date_updated = date_updated.split('>')
        date_updated = date_updated[1]
        return date_updated
    else:
        date_updated = 'Unknown'
        return date_updated

# %%
def get_word_count(dt_list, dd_list):
    # find word count index
    if 'Word Count' in dt_list:
        index = dt_list.index("Word Count")
        word_count = dd_list[index]
        word_count = word_count.replace(',','')
        word_count = word_count.split('>')
        word_count = int(word_count[1])
        return word_count
    else:
        word_count = 'Unknown'
        return word_count

# %%
def get_chapter_count(dt_list, dd_list):
    # find Chapter index
    if 'Chapters' in dt_list:
        index = dt_list.index("Chapters")
        chapter_count = dd_list[index]
        chapter_count = chapter_count.split('>')
        chapter_count = chapter_count[1]
        return chapter_count
    else:
        chapter_count = str(1)
        return chapter_count

# %%
def get_comment_count(dt_list, dd_list):
    # find comment count index
    if 'Comments' in dt_list:
        index = dt_list.index("Comments")
        comment_count = dd_list[index]
        comment_count = comment_count.split('>')
        comment_count = int(comment_count[1])
        return comment_count
    else:
        comment_count = 0
        return comment_count

# %%
def get_kudos_count(dt_list, dd_list):
    # find kudos count index
    if 'Kudos' in dt_list:
        index = dt_list.index("Kudos")
        kudos_count = dd_list[index]
        kudos_count = kudos_count.split('>')
        kudos_count = int(kudos_count[1])
        return kudos_count
    else:
        kudos_count = 0
        return kudos_count

# %%
def get_bookmarks_count(dt_list, dd_list):
    # find bookmarks count index
    if 'Bookmarks' in dt_list:
        index = dt_list.index("Bookmarks")
        bookmarks_count = dd_list[index]
        bookmarks_count = bookmarks_count[-1]
        bookmarks_count = int(bookmarks_count)
        return bookmarks_count

    else:
        bookmarks_count = 0
        return bookmarks_count

# %% [markdown]
# # Create Dictionary from html items

# %%
def create_fanwork_dict(dt_list, dd_list):
    fanwork_dict = {}

    # add rating
    rating = get_rating(dt_list, dd_list)
    fanwork_dict['Rating'] = get_rating(dt_list, dd_list)

    # add archive warning(s)
    fanwork_dict['Archive Warnings'] = get_warnings(dt_list, dd_list)

    # category
    fanwork_dict['Category'] = get_category(dt_list, dd_list)

    # add fandom
    fanwork_dict['Fandom'] = get_fandom(dt_list, dd_list)

    # add characters
    fanwork_dict['Characters'] = get_characters(dt_list, dd_list)

    # add relationships
    fanwork_dict['Relationships'] = get_relationships(dt_list, dd_list)

    # add additional tags
    fanwork_dict['Additional Tags'] = get_additional_tags(dt_list, dd_list)

    # add language
    fanwork_dict['Language'] = get_language(dt_list, dd_list)

    # add whether it is a series
    fanwork_dict['Is Series'] = is_series(dd_list)

    # add stats
    fanwork_dict['Date Published'] = get_date_published(dt_list, dd_list)
    fanwork_dict['Date Updated'] = get_date_updated(dt_list, dd_list)
    fanwork_dict['Word Count'] = get_word_count(dt_list, dd_list)
    fanwork_dict['Chapter Count'] = get_chapter_count(dt_list, dd_list)
    fanwork_dict['Comment Count'] = get_comment_count(dt_list, dd_list)
    fanwork_dict['Kudos Count'] = get_kudos_count(dt_list, dd_list)
    fanwork_dict['Bookmarks Count'] = get_bookmarks_count(dt_list, dd_list)

    return fanwork_dict

# %% [markdown]
# # Add fanworks_dict to master dictionary (all_works_dict)

# %%
def create_all_works_dict():
    dict_all_works = {}
    return dict_all_works

# %%
def append_all_works_dict(dict_fanwork, dict_all_works):
    current_length = len(dict_all_works)
    new_idx = current_length + 1
    dict_all_works[new_idx] = dict_fanwork
    return dict_all_works

# %% [markdown]
# # Convert master dictionary to json object

# %%
def convert_to_json(dict_all_works):
    json_string = json.dumps(dict_all_works, indent=4)
    return json_string

# %%
def save_json_to_file(json_string):
    with open('data/json_string.json', "w") as f:
        f.write(json_string)

# %% [markdown]
# # Testing

# %%
# test get_fanwork_links
fanwork_links = get_fanwork_links('../../data/fanwork_links.txt')
print(fanwork_links)
# Out:
# ['https://archiveofourown.org/works/80602681', 'https://archiveofourown.org/works/51518734', 'https://archiveofourown.org/works/51010177', 'https://archiveofourown.org/works/80156821', 'https://archiveofourown.org/works/74479381', 'https://archiveofourown.org/works/56574286', 'https://archiveofourown.org/works/75864761', 'https://archiveofourown.org/works/73925776', 'https://archiveofourown.org/works/69525656', 'https://archiveofourown.org/works/69696606', 'https://archiveofourown.org/works/69266581', 'https://archiveofourown.org/works/68678736', 'https://archiveofourown.org/works/59798779', 'https://archiveofourown.org/works/55118308', 'https://archiveofourown.org/works/66001534', 'https://archiveofourown.org/works/62477026', 'https://archiveofourown.org/works/62036794', 'https://archiveofourown.org/works/60847894', 'https://archiveofourown.org/works/51300544', 'https://archiveofourown.org/works/56817901', 'https://archiveofourown.org/works/56876515', 'https://archiveofourown.org/works/58577140', 'https://archiveofourown.org/works/58428907', 'https://archiveofourown.org/works/58397821', 'https://archiveofourown.org/works/58377157', 'https://archiveofourown.org/works/55745599', 'https://archiveofourown.org/works/57514030', 'https://archiveofourown.org/works/57373072', 'https://archiveofourown.org/works/57148285', 'https://archiveofourown.org/works/57049183', 'https://archiveofourown.org/works/57168277', 'https://archiveofourown.org/works/56944855', 'https://archiveofourown.org/works/56887570', 'https://archiveofourown.org/works/56832094', 'https://archiveofourown.org/works/56748733', 'https://archiveofourown.org/works/56530477', 'https://archiveofourown.org/works/56410426', 'https://archiveofourown.org/works/56396950', 'https://archiveofourown.org/works/56370673', 'https://archiveofourown.org/works/56348689', 'https://archiveofourown.org/works/56112163', 'https://archiveofourown.org/works/56104648', 'https://archiveofourown.org/works/55897618', 'https://archiveofourown.org/works/55858051', 'https://archiveofourown.org/works/55849537', 'https://archiveofourown.org/works/55829683', 'https://archiveofourown.org/works/55821961', 'https://archiveofourown.org/works/55602580', 'https://archiveofourown.org/works/55469746', 'https://archiveofourown.org/works/55495195', 'https://archiveofourown.org/works/55447729', 'https://archiveofourown.org/works/55024471', 'https://archiveofourown.org/works/54959626', 'https://archiveofourown.org/works/55205539', 'https://archiveofourown.org/works/55188448', 'https://archiveofourown.org/works/55022362', 'https://archiveofourown.org/works/54638023', 'https://archiveofourown.org/works/54777958', 'https://archiveofourown.org/works/54682489', 'https://archiveofourown.org/works/53537782', 'https://archiveofourown.org/works/54270886', 'https://archiveofourown.org/works/54199738', 'https://archiveofourown.org/works/54066016', 'https://archiveofourown.org/works/54070948', 'https://archiveofourown.org/works/53756806', 'https://archiveofourown.org/works/53629054', 'https://archiveofourown.org/works/53636989', 'https://archiveofourown.org/works/53557639', 'https://archiveofourown.org/works/53531353', 'https://archiveofourown.org/works/53501956', 'https://archiveofourown.org/works/53498773', 'https://archiveofourown.org/works/53485774', 'https://archiveofourown.org/works/53410531', 'https://archiveofourown.org/works/53358775', 'https://archiveofourown.org/works/53275300', 'https://archiveofourown.org/works/53228317', 'https://archiveofourown.org/works/53141194', 'https://archiveofourown.org/works/53209828', 'https://archiveofourown.org/works/53208346', 'https://archiveofourown.org/works/53108299', 'https://archiveofourown.org/works/53097769', 'https://archiveofourown.org/works/53132287', 'https://archiveofourown.org/works/53047816', 'https://archiveofourown.org/works/52897306', 'https://archiveofourown.org/works/52841056', 'https://archiveofourown.org/works/52826596', 'https://archiveofourown.org/works/52804864 ...

# %%
print(len(fanwork_links))
# Out:
# 211

# %% [markdown]
# ## Individual link

# %%
# test get_html_doc_fanworks
test_url = 'https://archiveofourown.org/works/73925776'
outer_html = get_fanwork_html(test_url)
print(outer_html)
# Out:
# TOS agreement section is present:  True
# Adult content warning is present:  True
# <div id="outer" class="wrapper">
#       <ul id="skiplinks"><li><a href="#main">Main Content</a></li></ul>
#       <noscript><p id="javascript-warning">While we&#39;ve done our best to make the core functionality of this site accessible without JavaScript, it will work better with it enabled. Please consider turning it on!</p></noscript>
#
# <!-- BEGIN header -->
#
# <header id="header" class="region">
#
#   <h1 class="heading">
#     <a href="/"><span>Archive of Our Own</span><img alt="Archive of Our Own" class="logo" src="/images/ao3_logos/logo_42.png"></a>
#   </h1>
#
#     <div id="login" class="dropdown" aria-haspopup="true">
#       <p class="user actions">
#         <a id="login-dropdown" href="/users/login?return_to=%2Fworks%2F73925776" class="dropdown-toggle" data-toggle="dropdown" data-target="#">Log In</a>
#       </p>
#       <div id="small_login" class="simple login">
# 	<form class="new_user" id="new_user_session_small" action="/users/login?return_to=%2Fworks%2F73925776" accept-charset="UTF-8" method="post"><input type="hidden" name="authenticity_token" value="G2zal2t8bn6dGRLYb_I5r7kab-qHkXDlPtW_9vWCRBsBQ6h9snPH4L5UDzcw3QPegg7cPxoKv4C1zWrRjzc_LQ" autocomplete="off">
#   <dl>
#     <dt><label for="user_session_login_small">Username or email:</label></dt>
#     <dd><input autocomplete="on" id="user_session_login_small" type="text" name="user[login]"></dd>
#     <dt><label for="user_session_password_small">Password:</label></dt>
#     <dd><input id="user_session_password_small" type="password" name="user[password]"></dd>
#   </dl>
#   <p class="submit actions">
#     <label for="user_remember_me_small" class="action">
#       <input type="checkbox" name="user[remember_me]" id="user_remember_me_small" value="1">Remember Me
#     </label>
#     <input type="submit" name="commit" value="Log In">
#   </p>
# </form>
# <ul class="footnote actions">
#   <li><a href="/users/password/new">Forgot password?</a></li>
#     <li>
#       <a href="/invite_requests">Get an Invitation</a>
#     </li>
# </ul>
#
# </div>
#
#     </div>
#
#   <nav aria-label="Site">
#     <ul class="primary navigation actions">
#       <li class="dropdown" aria-haspopup="true">
#         <a href="/menu/fandoms" class="dropdown-toggle" data-toggle="dropdown" data-target="#">Fandoms</a>
#         <ul class="menu dropdown-menu">
#   <li><a href="/media">All Fandoms</a></li>
#         <li id="medium_5"><a href="/media/Anime%20*a*%20Manga/fandoms">Anime &amp; Manga</a></li>
#         <li id="medium_3"><a href="/media/Books%20*a*%20Literature/fandoms">Books &amp; Literature</a></li>
#         <li id="medium_4"><a href="/media/Cartoons%20*a*%20Comics%20*a*%20Graphic%20Novels/fandoms">Cartoons &amp; Comics &amp; Graphic Novels</a></li>
#         <li id="medium_7"><a href="/media/Celebrities%20*a*%20Real%20People/fandoms">Celebrities &amp; Real People</a></li>
#         <li id="medium_2"><a href="/media/Movies/fandoms">Movies</a></li>
#         <li id="medium_6"><a href="/media/Music%20*a*%20Bands/fandoms">Music &amp; Bands</a></li>
#         <li id="medium_8"><a href="/media/Other%20Media/fandoms">Other Media</a></li>
#         <li id="medium_30198"><a href="/media/Theater/fandoms">Theater</a></li>
#         <li id="medium_1"><a href="/media/TV%20Shows/fandoms">TV Shows</a></li>
#         <li id="medium_476"><a href="/media/Video%20Games/fandoms">Video Games</a></li>
#         <li id="medium_9971"><a href="/media/Uncategorized%20Fandoms/fandoms">Uncategorized Fandoms</a></li>
# </ul>
#
#       </li>
#       <li class="dropdown" aria-haspopup="true">
#         <a href="/menu/browse" class="dropdown-toggle" data-toggle="dropdown" data-target="#">Browse</a>
#         <ul class="menu dropdown-menu">
#   <li><a href="/works">Works</a></li>
#   <li><a href="/bookmarks">Bookmarks</a></li>
#   <li><a href="/tags">Tags</a></li>
#   <li><a href="/collections">Collections</a></li>
# </ul>
#
#       </li>
#       <li class="dropdown" aria-haspopup="true">
#         <a href="/menu/search" class="dropdown-toggle" data-toggle="dropdown" data-target="#">Search</a>
#         <ul class="menu dropdown-menu">
#   <li><a href="/works/search">Works</a></li>
#   <li><a href="/bookmarks/search">Bookmarks</a></li>
#   <li><a href="/tags/search">Tags</a></li>
#   <li><a href="/people/search">People</a></li>
# </ul>
#
#       </li>
#       <li class="dropdown" aria-haspopup="true">
#         <a href="/menu/about" class="dropdown-toggle" data-toggle="dropdown" data-target="#">About</a>
#         <ul class="menu dropdown-menu">
#   <li><a href="/about">About Us</a></li>
#   <li><a href="/admin_posts">News</a></li>
#   <li><a href="/faq">FAQ</a></li>
#   <li><a href="/wrangling_guidelines">Wrangling Guidelines</a></li>
#   <li><a href="/donate">Donate or Volunteer</a></li>
# </ul>
#
#       </li>
#       <li class="search"><form class="search" id="search" role="search" aria-label="Work" action="/works/search" accept-charset="UTF-8" method="get">
#   <fieldset>
#     <p>
#       <label class="landmark" for="site_search">Work Search</label>
#       <input class="text" id="site_search" aria-describedby="site_search_tooltip" type="text" name="work_search[query]">
#       <span class="tip" role="tooltip" id="site_search_tooltip">tip: "uchiha sasuke/uzumaki naruto" angst kudos&gt;10</span>
#       <span class="submit actions"><input type="submit" value="Search" class="button"></span>
#     </p>
#   </fieldset>
# </form></li>
#     </ul>
#   </nav>
#
#
#
#   <div class="clear"></div>
#
# </header>
#
#
#
# <!-- END header -->
#
#       <div id="inner" class="wrapper">
#         <!-- BEGIN sidebar -->
#         <!-- END sidebar -->
#
#         <!-- BEGIN main -->
#         <div id="main" class="works-show region" role="main">
#
#           <div class="flash"></div>
#           <h2 class="landmark heading">Adult Content Warning</h2>
#
# <p class="caution notice">
#   This work could have adult content. If you continue, you have agreed that you are willing to see such content.
# </p>
#
# <ul class="actions">
#   <li>
#     <a href="/works/73925776?view_adult=true">Yes, Continue</a>
#   </li>
#   <li>
#     <a href="javascript:history.back()">No, Go Back</a>
#   </li>
# </ul>
#
# <p class="message footnote">
#   If you accept cookies from our site and you choose "Yes, Continue", you will not be asked again during this session (that is, until you close your browser). If you log in you can store your preference and never be asked again.
# </p>
#
# <div class="clear"></div>
#
# <ol class="work index group">
#   <li id="work_73925776" class="work blurb group work-73925776 user-223776" role="article">
#     <!--title, author, fandom-->
#   <div class="header module">
#     <!-- updated_at=1762694776 -->
#     <h4 class="heading">
#       <a href="/works/73925776">There are times life will rattle your bones</a>
#       by
#
#       <!-- do not cache -->
#       <a rel="author" href="/users/station_oracle/pseuds/station_oracle">station_oracle</a>
#
#
#
#
#
#     </h4>
#
#     <h5 class="fandoms heading">
#       <span class="landmark">Fandoms:</span>
#       <a class="tag" href="/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works">Candela Obscura (Critical Role Web Series)</a>
#       &nbsp;
#     </h5>
#
#     <!--required tags-->
#     <ul class="required-tags">
# <li><a class="help symbol question modal modal-attached" title="Symbols key" href="/help/symbols_key" aria-controls="modal"><span class="rating-explicit rating" title="Explicit"><span class="text">Explicit</span></span></a></li>
# <li><a class="help symbol question modal modal-attached" title="Symbols key" href="/help/symbols_key" aria-controls="modal"><span class="warning-no warnings" title="No Archive Warnings Apply"><span class="text">No Archive Warnings Apply</span></span></a></li>
# <li><a class="help symbol question modal modal-attached" title="Symbols key" href="/help/symbols_key" aria-controls="modal"><span class="category-slash category" title="M/M"><span class="text">M/M</span></span></a></li>
# <li><a class="help symbol question modal modal-attached" title="Symbols key" href="/help/symbols_key" aria-controls="modal"><span class="complete-no iswip" title="Work in Progress"><span class="text">Work in Progress</span></span></a></li>
# </ul>
#     <p class="datetime">09 Nov 2025</p>
#   </div>
#
#   <!--warnings again, cast, freeform tags-->
#   <h6 class="landmark heading">Tags</h6>
#   <ul class="tags commas">
#     <li class="warnings"><strong><a class="tag" href="/tags/No%20Archive%20Warnings%20Apply/works">No Archive Warnings Apply</a></strong></li><li class="relationships"><a class="tag" href="/tags/Leo%20Amicus*s*Original%20Character(s)/works">Leo Amicus/Original Character(s)</a></li><li class="characters"><a class="tag" href="/tags/Leo%20Amicus/works">Leo Amicus</a></li> <li class="characters"><a class="tag" href="/tags/Original%20Male%20Character(s)/works">Original Male Character(s)</a></li><li class="freeforms"><a class="tag" href="/tags/Circle%20of%20the%20Crimson%20Mirror%20(Candela%20Obscura)/works">Circle of the Crimson Mirror (Candela Obscura)</a></li> <li class="freeforms"><a class="tag" href="/tags/Boats%20and%20Ships/works">Boats and Ships</a></li> <li class="freeforms"><a class="tag" href="/tags/Crew%20of%20the%20Dandridge/works">Crew of the Dandridge</a></li> <li class="freeforms"><a class="tag" href="/tags/Missing%20Scene/works">Missing Scene</a></li> <li class="freeforms"><a class="tag" href="/tags/Blow%20Jobs/works">Blow Jobs</a></li> <li class="freeforms"><a class="tag" href="/tags/Anal%20Sex/works">Anal Sex</a></li> <li class="freeforms"><a class="tag" href="/tags/Topping%20from%20the%20Bottom/works">Topping from the Bottom</a></li> <li class="freeforms"><a class="tag" href="/tags/Plot%20What%20Plot*s*Porn%20Without%20Plot/works">Plot What Plot/Porn Without Plot</a></li> <li class="freeforms"><a class="tag" href="/tags/almost/works">almost</a></li> <li class="freeforms"><a class="tag" href="/tags/Age%20Difference/works">Age Difference</a></li>
#   </ul>
#
#   <!--summary-->
#     <h6 class="landmark heading">Summary</h6>
#     <blockquote class="userstuff summary">
#       <p><i>Leo, as his friends called him, was an exotic bird of a man, clearly trapped on the ship. The fabric of his red coat contrasted with the sea around them, glimmering like materials Avery had seen in precious shipping crates made of dark, polished wood, rather than worn by people. He looked important and wealthy enough not to have a care in the world, but there was something familiar about him too. Avery couldn’t take his eyes off of him since their weird group boarded the Dandridge.</i></p><p>A young sailor decides to pursue a wealthy passenger. They have a good time. Missing scenes from an NPC's point of view. Chapter 1 is the setup, Chapter 2 is porn.<br>Rated S for Smut, just like Aimee wanted.</p>
#     </blockquote>
#
#
#   <!--stats-->
#
#   <dl class="stats">
#       <dt class="language">Language:</dt>
#       <dd class="language" lang="en">English</dd>
#     <dt class="words">Words:</dt>
#     <dd class="words">1,070</dd>
#     <dt class="chapters">Chapters:</dt>
#     <dd class="chapters">1/2</dd>
#
#
#
#     <dt class="comments">Comments:</dt>
#     <dd class="comments"><a href="/works/73925776?show_comments=true#comments">2</a></dd>
#
#     <dt class="kudos">Kudos:</dt>
#     <dd class="kudos"><a href="/works/73925776#kudos">2</a></dd>
#
#
#   <dt class="hits">Hits:</dt>
#   <dd class="hits">28</dd>
#
#   </dl>
#
#
# </li>
#
# </ol>
#
#           <div class="clear"><!--presentational--></div>
#         </div>
#         <!-- END main -->
#       </div>
#       <!-- BEGIN footer -->
# <div id="footer" role="contentinfo" class="region">
#   <h3 class="landmark heading">Footer</h3>
#   <ul class="navigation actions">
#     <li class="module group">
#       <h4 class="heading">About the Archive</h4>
#       <ul class="menu">
#         <li><a href="/site_map">Site Map</a></li>
#         <li><a href="/diversity">Diversity Statement</a></li>
#         <li><a href="/tos">Terms of Service</a></li>
#         <li><a href="/content">Content Policy</a></li>
#         <li><a href="/privacy">Privacy Policy</a></li>
#         <li><a href="/takedown">DMCA &amp; TIDA Policies</a> </li>
#         <li><a href="https://www.otwstatus.org">Site Status</a></li>
#       </ul>
#     </li>
#     <li class="module group">
#       <h4 class="heading">Contact Us</h4>
#       <ul class="menu">
#         <li><a href="/abuse_reports/new">Policy Questions &amp; Abuse Reports</a></li>
#         <li><a href="/support">Technical Support &amp; Feedback</a></li>
#       </ul>
#     </li>
#     <li class="module group">
#       <h4 class="heading">Development</h4>
#       <ul class="menu">
#           <li>
#             <a href="https://github.com/otwcode/otwarchive/commits/v0.9.481.0">otwarchive v0.9.481.0</a>
#           </li>
#         <li><a href="/known_issues">Known Issues</a></li>
#         <li>
#           <a title="View License" href="https://www.gnu.org/licenses/old-licenses/gpl-2.0.html">GPL-2.0-or-later</a> by the <a title="Organization for Transformative Works" href="https://transformativeworks.org/">OTW</a>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </div>
# <!-- END footer -->
#
#     </div>

# %%
# get BeautifulSoup object
soup = get_soup(outer_html)
print(soup)
# Out:
# <div class="wrapper" id="outer">
# <ul id="skiplinks"><li><a href="#main">Main Content</a></li></ul>
# <noscript><p id="javascript-warning">While we've done our best to make the core functionality of this site accessible without JavaScript, it will work better with it enabled. Please consider turning it on!</p></noscript>
# <!-- BEGIN header -->
# <header class="region" id="header">
# <h1 class="heading">
# <a href="/"><span>Archive of Our Own</span><img alt="Archive of Our Own" class="logo" src="/images/ao3_logos/logo_42.png"/></a>
# </h1>
# <div aria-haspopup="true" class="dropdown" id="login">
# <p class="user actions">
# <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="/users/login?return_to=%2Fworks%2F73925776" id="login-dropdown">Log In</a>
# </p>
# <div class="simple login" id="small_login">
# <form accept-charset="UTF-8" action="/users/login?return_to=%2Fworks%2F73925776" class="new_user" id="new_user_session_small" method="post"><input autocomplete="off" name="authenticity_token" type="hidden" value="G2zal2t8bn6dGRLYb_I5r7kab-qHkXDlPtW_9vWCRBsBQ6h9snPH4L5UDzcw3QPegg7cPxoKv4C1zWrRjzc_LQ"/>
# <dl>
# <dt><label for="user_session_login_small">Username or email:</label></dt>
# <dd><input autocomplete="on" id="user_session_login_small" name="user[login]" type="text"/></dd>
# <dt><label for="user_session_password_small">Password:</label></dt>
# <dd><input id="user_session_password_small" name="user[password]" type="password"/></dd>
# </dl>
# <p class="submit actions">
# <label class="action" for="user_remember_me_small">
# <input id="user_remember_me_small" name="user[remember_me]" type="checkbox" value="1"/>Remember Me
#     </label>
# <input name="commit" type="submit" value="Log In"/>
# </p>
# </form>
# <ul class="footnote actions">
# <li><a href="/users/password/new">Forgot password?</a></li>
# <li>
# <a href="/invite_requests">Get an Invitation</a>
# </li>
# </ul>
# </div>
# </div>
# <nav aria-label="Site">
# <ul class="primary navigation actions">
# <li aria-haspopup="true" class="dropdown">
# <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="/menu/fandoms">Fandoms</a>
# <ul class="menu dropdown-menu">
# <li><a href="/media">All Fandoms</a></li>
# <li id="medium_5"><a href="/media/Anime%20*a*%20Manga/fandoms">Anime &amp; Manga</a></li>
# <li id="medium_3"><a href="/media/Books%20*a*%20Literature/fandoms">Books &amp; Literature</a></li>
# <li id="medium_4"><a href="/media/Cartoons%20*a*%20Comics%20*a*%20Graphic%20Novels/fandoms">Cartoons &amp; Comics &amp; Graphic Novels</a></li>
# <li id="medium_7"><a href="/media/Celebrities%20*a*%20Real%20People/fandoms">Celebrities &amp; Real People</a></li>
# <li id="medium_2"><a href="/media/Movies/fandoms">Movies</a></li>
# <li id="medium_6"><a href="/media/Music%20*a*%20Bands/fandoms">Music &amp; Bands</a></li>
# <li id="medium_8"><a href="/media/Other%20Media/fandoms">Other Media</a></li>
# <li id="medium_30198"><a href="/media/Theater/fandoms">Theater</a></li>
# <li id="medium_1"><a href="/media/TV%20Shows/fandoms">TV Shows</a></li>
# <li id="medium_476"><a href="/media/Video%20Games/fandoms">Video Games</a></li>
# <li id="medium_9971"><a href="/media/Uncategorized%20Fandoms/fandoms">Uncategorized Fandoms</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="dropdown">
# <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="/menu/browse">Browse</a>
# <ul class="menu dropdown-menu">
# <li><a href="/works">Works</a></li>
# <li><a href="/bookmarks">Bookmarks</a></li>
# <li><a href="/tags">Tags</a></li>
# <li><a href="/collections">Collections</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="dropdown">
# <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="/menu/search">Search</a>
# <ul class="menu dropdown-menu">
# <li><a href="/works/search">Works</a></li>
# <li><a href="/bookmarks/search">Bookmarks</a></li>
# <li><a href="/tags/search">Tags</a></li>
# <li><a href="/people/search">People</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="dropdown">
# <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="/menu/about">About</a>
# <ul class="menu dropdown-menu">
# <li><a href="/about">About Us</a></li>
# <li><a href="/admin_posts">News</a></li>
# <li><a href="/faq">FAQ</a></li>
# <li><a href="/wrangling_guidelines">Wrangling Guidelines</a></li>
# <li><a href="/donate">Donate or Volunteer</a></li>
# </ul>
# </li>
# <li class="search"><form accept-charset="UTF-8" action="/works/search" aria-label="Work" class="search" id="search" method="get" role="search">
# <fieldset>
# <p>
# <label class="landmark" for="site_search">Work Search</label>
# <input aria-describedby="site_search_tooltip" class="text" id="site_search" name="work_search[query]" type="text"/>
# <span class="tip" id="site_search_tooltip" role="tooltip">tip: "uchiha sasuke/uzumaki naruto" angst kudos&gt;10</span>
# <span class="submit actions"><input class="button" type="submit" value="Search"/></span>
# </p>
# </fieldset>
# </form></li>
# </ul>
# </nav>
# <div class="clear"></div>
# </header>
# <!-- END header -->
# <div class="wrapper" id="inner">
# <!-- BEGIN sidebar -->
# <!-- END sidebar -->
# <!-- BEGIN main -->
# <div class="works-show region" id="main" role="main">
# <div class="flash"></div>
# <h2 class="landmark heading">Adult Content Warning</h2>
# <p class="caution notice">
#   This work could have adult content. If you continue, you have agreed that you are willing to see such content.
# </p>
# <ul class="actions">
# <li>
# <a href="/works/73925776?view_adult=true">Yes, Continue</a>
# </li>
# <li>
# <a href="javascript:history.back()">No, Go Back</a>
# </li>
# </ul>
# <p class="message footnote">
#   If you accept cookies from our site and you choose "Yes, Continue", you will not be asked again during this session (that is, until you close your browser). If you log in you can store your preference and never be asked again.
# </p>
# <div class="clear"></div>
# <ol class="work index group">
# <li class="work blurb group work-73925776 user-223776" id="work_73925776" role="article">
# <!--title, author, fandom-->
# <div class="header module">
# <!-- updated_at=1762694776 -->
# <h4 class="heading">
# <a href="/works/73925776">There are times life will rattle your bones</a>
#       by
#
#       <!-- do not cache -->
# <a href="/users/station_oracle/pseuds/station_oracle" rel="author">station_oracle</a>
# </h4>
# <h5 class="fandoms heading">
# <span class="landmark">Fandoms:</span>
# <a class="tag" href="/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works">Candela Obscura (Critical Role Web Series)</a>
#
#     </h5>
# <!--required tags-->
# <ul class="required-tags">
# <li><a aria-controls="modal" class="help symbol question modal modal-attached" href="/help/symbols_key" title="Symbols key"><span class="rating-explicit rating" title="Explicit"><span class="text">Explicit</span></span></a></li>
# <li><a aria-controls="modal" class="help symbol question modal modal-attached" href="/help/symbols_key" title="Symbols key"><span class="warning-no warnings" title="No Archive Warnings Apply"><span class="text">No Archive Warnings Apply</span></span></a></li>
# <li><a aria-controls="modal" class="help symbol question modal modal-attached" href="/help/symbols_key" title="Symbols key"><span class="category-slash category" title="M/M"><span class="text">M/M</span></span></a></li>
# <li><a aria-controls="modal" class="help symbol question modal modal-attached" href="/help/symbols_key" title="Symbols key"><span class="complete-no iswip" title="Work in Progress"><span class="text">Work in Progress</span></span></a></li>
# </ul>
# <p class="datetime">09 Nov 2025</p>
# </div>
# <!--warnings again, cast, freeform tags-->
# <h6 class="landmark heading">Tags</h6>
# <ul class="tags commas">
# <li class="warnings"><strong><a class="tag" href="/tags/No%20Archive%20Warnings%20Apply/works">No Archive Warnings Apply</a></strong></li><li class="relationships"><a class="tag" href="/tags/Leo%20Amicus*s*Original%20Character(s)/works">Leo Amicus/Original Character(s)</a></li><li class="characters"><a class="tag" href="/tags/Leo%20Amicus/works">Leo Amicus</a></li> <li class="characters"><a class="tag" href="/tags/Original%20Male%20Character(s)/works">Original Male Character(s)</a></li><li class="freeforms"><a class="tag" href="/tags/Circle%20of%20the%20Crimson%20Mirror%20(Candela%20Obscura)/works">Circle of the Crimson Mirror (Candela Obscura)</a></li> <li class="freeforms"><a class="tag" href="/tags/Boats%20and%20Ships/works">Boats and Ships</a></li> <li class="freeforms"><a class="tag" href="/tags/Crew%20of%20the%20Dandridge/works">Crew of the Dandridge</a></li> <li class="freeforms"><a class="tag" href="/tags/Missing%20Scene/works">Missing Scene</a></li> <li class="freeforms"><a class="tag" href="/tags/Blow%20Jobs/works">Blow Jobs</a></li> <li class="freeforms"><a class="tag" href="/tags/Anal%20Sex/works">Anal Sex</a></li> <li class="freeforms"><a class="tag" href="/tags/Topping%20from%20the%20Bottom/works">Topping from the Bottom</a></li> <li class="freeforms"><a class="tag" href="/tags/Plot%20What%20Plot*s*Porn%20Without%20Plot/works">Plot What Plot/Porn Without Plot</a></li> <li class="freeforms"><a class="tag" href="/tags/almost/works">almost</a></li> <li class="freeforms"><a class="tag" href="/tags/Age%20Difference/works">Age Difference</a></li>
# </ul>
# <!--summary-->
# <h6 class="landmark heading">Summary</h6>
# <blockquote class="userstuff summary">
# <p><i>Leo, as his friends called him, was an exotic bird of a man, clearly trapped on the ship. The fabric of his red coat contrasted with the sea around them, glimmering like materials Avery had seen in precious shipping crates made of dark, polished wood, rather than worn by people. He looked important and wealthy enough not to have a care in the world, but there was something familiar about him too. Avery couldn’t take his eyes off of him since their weird group boarded the Dandridge.</i></p><p>A young sailor decides to pursue a wealthy passenger. They have a good time. Missing scenes from an NPC's point of view. Chapter 1 is the setup, Chapter 2 is porn.<br/>Rated S for Smut, just like Aimee wanted.</p>
# </blockquote>
# <!--stats-->
# <dl class="stats">
# <dt class="language">Language:</dt>
# <dd class="language" lang="en">English</dd>
# <dt class="words">Words:</dt>
# <dd class="words">1,070</dd>
# <dt class="chapters">Chapters:</dt>
# <dd class="chapters">1/2</dd>
# <dt class="comments">Comments:</dt>
# <dd class="comments"><a href="/works/73925776?show_comments=true#comments">2</a></dd>
# <dt class="kudos">Kudos:</dt>
# <dd class="kudos"><a href="/works/73925776#kudos">2</a></dd>
# <dt class="hits">Hits:</dt>
# <dd class="hits">28</dd>
# </dl>
# </li>
# </ol>
# <div class="clear"><!--presentational--></div>
# </div>
# <!-- END main -->
# </div>
# <!-- BEGIN footer -->
# <div class="region" id="footer" role="contentinfo">
# <h3 class="landmark heading">Footer</h3>
# <ul class="navigation actions">
# <li class="module group">
# <h4 class="heading">About the Archive</h4>
# <ul class="menu">
# <li><a href="/site_map">Site Map</a></li>
# <li><a href="/diversity">Diversity Statement</a></li>
# <li><a href="/tos">Terms of Service</a></li>
# <li><a href="/content">Content Policy</a></li>
# <li><a href="/privacy">Privacy Policy</a></li>
# <li><a href="/takedown">DMCA &amp; TIDA Policies</a> </li>
# <li><a href="https://www.otwstatus.org">Site Status</a></li>
# </ul>
# </li>
# <li class="module group">
# <h4 class="heading">Contact Us</h4>
# <ul class="menu">
# <li><a href="/abuse_reports/new">Policy Questions &amp; Abuse Reports</a></li>
# <li><a href="/support">Technical Support &amp; Feedback</a></li>
# </ul>
# </li>
# <li class="module group">
# <h4 class="heading">Development</h4>
# <ul class="menu">
# <li>
# <a href="https://github.com/otwcode/otwarchive/commits/v0.9.481.0">otwarchive v0.9.481.0</a>
# </li>
# <li><a href="/known_issues">Known Issues</a></li>
# <li>
# <a href="https://www.gnu.org/licenses/old-licenses/gpl-2.0.html" title="View License">GPL-2.0-or-later</a> by the <a href="https://transformativeworks.org/" title="Organization for Transformative Works">OTW</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <!-- END footer -->
# </div>

# %%
# test get_all_dt
all_dt = get_all_dt(soup)
print(all_dt)
# Out:
# [<dt><label for="user_session_login_small">Username or email:</label></dt>, <dt><label for="user_session_password_small">Password:</label></dt>, <dt class="language">Language:</dt>, <dt class="words">Words:</dt>, <dt class="chapters">Chapters:</dt>, <dt class="comments">Comments:</dt>, <dt class="kudos">Kudos:</dt>, <dt class="hits">Hits:</dt>]

# %%
all_dt_updated = update_all_dt(all_dt)
print(all_dt_updated)
# Out:
# ['user_session_login', 'user_session_password', 'Language', 'Word Count', 'Chapters', 'Comments', 'Kudos', 'Bookmarks', 'Hits']

# %%
print(len(all_dt))
# Out:
# 9

# %%
# test get_all_dd
all_dd = get_all_dd(soup)

# %%
all_dd_stripped = strip_dd(all_dd)

# %%
# test cleanup_fandom_tags
all_dd_stripped = cleanup_fandom_tags(all_dd_stripped)

# %%
# test cleanup_relationship_tags
all_dd_stripped = cleanup_relationship_tags(all_dd_stripped)

# %%
# test cleanup_character_tags
all_dd_stripped = cleanup_character_tags(all_dd_stripped)

# %%
# test cleanup_additional_tags
all_dd_stripped = cleanup_additional_tags(all_dd_stripped)

# %%
# test get_ratings
get_rating(all_dt_updated, all_dd_stripped)
# Out:
# 'Unknown'

# %%
# test get_warnings
get_warnings(all_dt_updated, all_dd_stripped)
# Out:
# 'No warnings listed'

# %%
# test get_category
get_category(all_dt_updated, all_dd_stripped)
# Out:
# 'Gen'

# %%
# test get_language
language = get_language(all_dt_updated, all_dd_stripped)
print(language)
# Out:
# English

# %%
# test get_fandom
get_fandom(all_dt_updated, all_dd_stripped)
# Out:
# ['',
#  'Private Nightmares | Project Ghostlight',
#  'Candela Obscura (Critical Role Web Series)']

# %%
# test get_relationships
get_relationships(all_dt_updated, all_dd_stripped)
# Out:
# ['',
#  'Eddie & Katie (Private Nightmares)',
#  'Naomi & Jade (Private Nightmares)',
#  'Eddie & Jade (Private Nightmares)',
#  'Gable & Jade (Private Nightmares)']

# %%
# test get_characters
get_characters(all_dt_updated, all_dd_stripped)
# Out:
# ['',
#  'Katie (Private Nightmares)',
#  'Gable (Private Nightmares)',
#  'Jade (Private Nightmares)',
#  'Eddie (Private Nightmares)',
#  'Naomi (Private Nightmares)',
#  'Robert (Private Nightmares)',
#  'Malcom Trills (Candela Obscura)',
#  'Edgar Lycoris',
#  'Horatio (Private Nightmares)',
#  'Vulo (Private Nightmares)',
#  'Manny (Private Nightmares)',
#  'Cosmo Grimm (Candela Obscura)']

# %%
# test get_additional_tags
get_additional_tags(all_dt_updated, all_dd_stripped)
# Out:
# ['',
#  'Vampires',
#  'Gaslamp Fantasy',
#  'Horror',
#  'Monster - Freeform',
#  'Blood',
#  'Body Horror',
#  'Autopsy',
#  'Mystery',
#  "don't look too hard at the Candela timeline"]

# %%
is_series(all_dd_stripped)
# Out:
# False

# %%
# test get_date_published
date_published = get_date_published(all_dt_updated, all_dd_stripped)
print(date_published)
print(type(date_published))
# Out:
# 2026-03-04
# <class 'str'>

# %%
# test get_date_updated
date_updated = get_date_updated(all_dt_updated, all_dd_stripped)
print(date_updated)
print(type(date_updated))
# Out:
# 2026-05-12
# <class 'str'>

# %%
# test get_word_count
word_count = get_word_count(all_dt_updated, all_dd_stripped)
print(word_count)
# Out:
# 14223

# %%
# test get_chapter_count
chapter_count = get_chapter_count(all_dt_updated, all_dd_stripped)
print(chapter_count)
# Out:
# 2/?

# %%
# test get_comment_count
comment_count = get_comment_count(all_dt_updated, all_dd_stripped)
print(comment_count)
# Out:
# 4

# %%
# test get_kudos_count
kudos_count = get_kudos_count(all_dt_updated, all_dd_stripped)
print(kudos_count)
# Out:
# 6

# %%
# test get_bookmarks_count
bookmarks_count = get_bookmarks_count(all_dt_updated, all_dd_stripped)
print(bookmarks_count)
# Out:
# 2

# %%
# test create_fanwork_dictionary
test_dict = create_fanwork_dict(all_dt_updated, all_dd_stripped)
print(test_dict)
# Out:
# {'Rating': 'Mature', 'Archive Warnings': 'Graphic Depictions Of Violence', 'Category': 'Gen', 'Fandom': ['', 'Private Nightmares | Project Ghostlight', 'Candela Obscura (Critical Role Web Series)'], 'Characters': ['', 'Katie (Private Nightmares)', 'Gable (Private Nightmares)', 'Jade (Private Nightmares)', 'Eddie (Private Nightmares)', 'Naomi (Private Nightmares)', 'Robert (Private Nightmares)', 'Malcom Trills (Candela Obscura)', 'Edgar Lycoris', 'Horatio (Private Nightmares)', 'Vulo (Private Nightmares)', 'Manny (Private Nightmares)', 'Cosmo Grimm (Candela Obscura)'], 'Relationships': ['', 'Eddie & Katie (Private Nightmares)', 'Naomi & Jade (Private Nightmares)', 'Eddie & Jade (Private Nightmares)', 'Gable & Jade (Private Nightmares)'], 'Additional Tags': ['', 'Vampires', 'Gaslamp Fantasy', 'Horror', 'Monster - Freeform', 'Blood', 'Body Horror', 'Autopsy', 'Mystery', "don't look too hard at the Candela timeline"], 'Language': 'English', 'Is Series': False, 'Date Published': '2026-03-04', 'Date Updated': '2026-05-12', 'Word Count': 14223, 'Chapter Count': '2/?', 'Comment Count': 4, 'Kudos Count': 6, 'Bookmarks Count': 2}

# %%
# test append_all_works_dict
append_all_works_dict(test_dict)
# Out:
# {1: {'Rating': 'Mature',
#   'Archive Warnings': 'Graphic Depictions Of Violence',
#   'Category': 'Gen',
#   'Fandom': ['',
#    'Private Nightmares | Project Ghostlight',
#    'Candela Obscura (Critical Role Web Series)'],
#   'Characters': ['',
#    'Katie (Private Nightmares)',
#    'Gable (Private Nightmares)',
#    'Jade (Private Nightmares)',
#    'Eddie (Private Nightmares)',
#    'Naomi (Private Nightmares)',
#    'Robert (Private Nightmares)',
#    'Malcom Trills (Candela Obscura)',
#    'Edgar Lycoris',
#    'Horatio (Private Nightmares)',
#    'Vulo (Private Nightmares)',
#    'Manny (Private Nightmares)',
#    'Cosmo Grimm (Candela Obscura)'],
#   'Relationships': ['',
#    'Eddie & Katie (Private Nightmares)',
#    'Naomi & Jade (Private Nightmares)',
#    'Eddie & Jade (Private Nightmares)',
#    'Gable & Jade (Private Nightmares)'],
#   'Additional Tags': ['',
#    'Vampires',
#    'Gaslamp Fantasy',
#    'Horror',
#    'Monster - Freeform',
#    'Blood',
#    'Body Horror',
#    'Autopsy',
#    'Mystery',
#    "don't look too hard at the Candela timeline"],
#   'Language': 'English',
#   'Is Series': False,
#   'Date Published': '2026-03-04',
#   'Date Updated': '2026-05-12',
#   'Word Count': 14223,
#   'Chapter Count': '2/?',
#   'Comment Count': 4,
#   'Kudos Count': 6,
#   'Bookmarks Count': 2}}

# %%
print(len(all_works_dict))
# Out:
# 1

# %%
# test convert_to_json
test_json = convert_to_json(all_works_dict)
print(test_json)

# %%
print(type(test_json))

# %%
# test save_json_to_file
save_json_to_file(test_json)

# %% [markdown]
# ## First 10 fanworks

# %%
first_10_fanworks = fanwork_links[0:10]
print(first_10_fanworks)
# Out:
# ['https://archiveofourown.org/works/80602681', 'https://archiveofourown.org/works/51518734', 'https://archiveofourown.org/works/51010177', 'https://archiveofourown.org/works/80156821', 'https://archiveofourown.org/works/74479381', 'https://archiveofourown.org/works/56574286', 'https://archiveofourown.org/works/75864761', 'https://archiveofourown.org/works/73925776', 'https://archiveofourown.org/works/69525656', 'https://archiveofourown.org/works/69696606']

# %%
## first10works_dict
total_fanworks = len(first_10_fanworks)
first10works_dict = {}
for i in range(len(first_10_fanworks)):
    print("Current fanwork link:", str(i+1), "of", total_fanworks)

    ## load fanworks and create soup objects
    soup = get_html_doc_fanworks(first_10_fanworks[i])
    all_dt = get_all_dt(soup)
    all_dt_updated = update_all_dt(all_dt)
    # print(all_dt_updated)
    all_dd = get_all_dd(soup)
    print("Successfully loaded fanworks and created soup objects for link", str(i+1))

    ## clean up all_dd
    all_dd_stripped = strip_dd(all_dd)
    # print(len(all_dd_stripped))
    all_dd_stripped = cleanup_fandom_tags(all_dd_stripped)
    all_dd_stripped = cleanup_relationship_tags(all_dd_stripped)
    all_dd_stripped = cleanup_character_tags(all_dd_stripped)
    all_dd_stripped = cleanup_additional_tags(all_dd_stripped)
    print("Successfully cleaned all_dd_stripped for link", str(i+1))

    ## create individual fanwork dictionary
    fanwork_dict = create_fanwork_dict(all_dt_updated, all_dd_stripped)
    # print(fanwork_dict)
    print("Successfully created individual fanwork dictionary for link", str(i+1))

    ## append fanwork dictionary to all_works_dict1
    # first10works_dict = create_all_works_dict()
    append_all_works_dict(fanwork_dict, first10works_dict)
    print("Successfully appended individual fanwork dictionary", str(i+1), "to first10works_dict.")
# Out:
# Current fanwork link: 1 of 10
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to first10works_dict.
# Current fanwork link: 2 of 10
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to first10works_dict.
# Current fanwork link: 3 of 10
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to first10works_dict.
# Current fanwork link: 4 of 10
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to first10works_dict.
# Current fanwork link: 5 of 10
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to first10works_dict.
# Current fanwork link: 6 of 10
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to first10works_dict.
# Current fanwork link: 7 of 10
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to first10works_dict.
# Current fanwork link: 8 of 10
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to first10works_dict.
# Current fanwork link: 9 of 10
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to first10works_dict.
# Current fanwork link: 10 of 10
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to first10works_dict.

# %%
print(first10works_dict)
# Out:
# {1: {'Rating': 'Mature', 'Archive Warnings': 'Graphic Depictions Of Violence', 'Category': 'Gen', 'Fandom': ['', 'Private Nightmares | Project Ghostlight', 'Candela Obscura (Critical Role Web Series)'], 'Characters': ['', 'Katie (Private Nightmares)', 'Gable (Private Nightmares)', 'Jade (Private Nightmares)', 'Eddie (Private Nightmares)', 'Naomi (Private Nightmares)', 'Robert (Private Nightmares)', 'Malcom Trills (Candela Obscura)', 'Edgar Lycoris', 'Horatio (Private Nightmares)', 'Vulo (Private Nightmares)', 'Manny (Private Nightmares)', 'Cosmo Grimm (Candela Obscura)'], 'Relationships': ['', 'Eddie & Katie (Private Nightmares)', 'Naomi & Jade (Private Nightmares)', 'Eddie & Jade (Private Nightmares)', 'Gable & Jade (Private Nightmares)'], 'Additional Tags': ['', 'Vampires', 'Gaslamp Fantasy', 'Horror', 'Monster - Freeform', 'Blood', 'Body Horror', 'Autopsy', 'Mystery', "don't look too hard at the Candela timeline"], 'Language': 'English', 'Is Series': False, 'Date Published': '2026-03-04', 'Date Updated': '2026-05-12', 'Word Count': 14223, 'Chapter Count': '2/?', 'Comment Count': 4, 'Kudos Count': 6, 'Bookmarks Count': 2}, 2: {'Rating': 'Unknown', 'Archive Warnings': 'No warnings listed', 'Category': 'Unknown', 'Fandom': 'No fandoms listed', 'Characters': 'No characters listed', 'Relationships': 'No relationships listed', 'Additional Tags': 'No additional tags', 'Language': 'Unknown', 'Is Series': None, 'Date Published': 'Unknown', 'Date Updated': 'Unknown', 'Word Count': 'Unknown', 'Chapter Count': '1', 'Comment Count': 0, 'Kudos Count': 0, 'Bookmarks Count': 0}, 3: {'Rating': 'Explicit', 'Archive Warnings': 'Creator Chose Not To Use Archive Warnings', 'Category': '/tags/M*s*M/works">M/M', 'Fandom': ['', 'Candela Obscura (Critical Role Web Series)'], 'Characters': ['', 'Sean Finnerty (Candela Obscura)', 'Nathaniel Trapp', 'Beatrix Monroe | Auntie Bee', 'Jinnah "Jean" Basar', 'Marion Collodi', 'Arlo Black (Candela Obscura)', 'Original Characters'], 'Relationships': ['', 'Sean Finnerty/Nathaniel Trapp'], 'Additional Tags': ['', 'Alternate Universe - Canon Divergence', 'Eventual Romance', 'Eventual Smut', 'Light Dom/sub', 'Light Angst', 'Not Beta Read', 'Post-Episode: s02e02 Flesh and Blood (Candela Obscura)', "sean finnerty's self destructive behavior", 'Anal Sex', 'Threesome - F/M/M'], 'Language': 'English', 'Is Series': False, 'Date Published': '2023-10-21', 'Date Updated': '2026-03-08', 'Word Count': 68991, 'Chapter Count': '9/10', 'Comment Count': 69, 'Kudos Count': 139, 'Bookmarks Count': 5}, 4: {'Rating': 'General Audiences', 'Archive Warnings': 'No Archive Warnings Apply', 'Category': 'Gen', 'Fandom': ['', 'Candela Obscura (Critical Role Web Series)'], 'Characters': ['', 'Sean Finnerty (Candela Obscura)', 'Nathaniel Trapp', 'Marion Collodi', 'Jinnah "Jean" Basar'], 'Relationships': ['', 'Circle of Needle and Thread - Relationship'], 'Additional Tags': ['', 'One Shot', 'Gen Work', 'Circle of Needle and Thread (Candela Obscura)', 'Friendship', 'Found Family', 'Chapter House (Candela Obscura)', 'Humor', 'When is a haunted house not haunted? oh - when two of you are secretly sleeping there without telling literally anyone else about it'], 'Language': 'English', 'Is Series': False, 'Date Published': '2026-02-24', 'Date Updated': '2026-02-24', 'Word Count': 1498, 'Chapter Count': '1/1', 'Comment Count': 2, 'Kudos Count': 9, 'Bookmarks Count': 0}, 5: {'Rating': 'Teen And Up Audiences', 'Archive Warnings': 'No Archive Warnings Apply', 'Category': 'Gen', 'Fandom': ['', 'Candela Obscura (Critical Role Web Series)'], 'Characters': ['', 'Grimoria (Candela Obscura)', 'Leo Amicus', 'Malcolm Trills', 'Edgar Lycoris'], 'Relationships': ['', 'Grimoria & Malcolm Trills', 'Leo Amicus & Grimoria', 'Grimoria & Edgar Lycoris', 'Leo Amicus & Grimoria & Edgar Lycoris & Malcolm Trills'], 'Additional Tags': ['', 'Hurt/Comfort', 'Sickfic', 'Neglect', 'the foggs suck', "but grim's three self-appointed dads are there for her", 'Found Family', 'Flu ...

# %%
print(len(first10works_dict))
# Out:
# 10

# %%
## convert to json and save to file
first10works_json = convert_to_json(first10works_dict)
with open('./data/first10works.json', "w") as f:
    f.write(first10works_json)

# %% [markdown]
# ## First 20 fanworks - for G8

# %%
first_20_fanworks = fanwork_links[0:20]
print(first_20_fanworks)
# Out:
# ['https://archiveofourown.org/works/80602681', 'https://archiveofourown.org/works/51518734', 'https://archiveofourown.org/works/51010177', 'https://archiveofourown.org/works/80156821', 'https://archiveofourown.org/works/74479381', 'https://archiveofourown.org/works/56574286', 'https://archiveofourown.org/works/75864761', 'https://archiveofourown.org/works/73925776', 'https://archiveofourown.org/works/69525656', 'https://archiveofourown.org/works/69696606', 'https://archiveofourown.org/works/69266581', 'https://archiveofourown.org/works/68678736', 'https://archiveofourown.org/works/59798779', 'https://archiveofourown.org/works/55118308', 'https://archiveofourown.org/works/66001534', 'https://archiveofourown.org/works/62477026', 'https://archiveofourown.org/works/62036794', 'https://archiveofourown.org/works/60847894', 'https://archiveofourown.org/works/51300544', 'https://archiveofourown.org/works/56817901']

# %%
## first20works_dict
total_fanworks = len(first_20_fanworks)
first20works_dict = {}
for i in range(len(first_20_fanworks)):
    print("Current fanwork link:", str(i+1), "of", total_fanworks)

    ## load fanworks and create soup objects
    soup = get_html_doc_fanworks(first_20_fanworks[i])
    all_dt = get_all_dt(soup)
    all_dt_updated = update_all_dt(all_dt)
    # print(all_dt_updated)
    all_dd = get_all_dd(soup)
    print("Successfully loaded fanworks and created soup objects for link", str(i+1))

    ## clean up all_dd
    all_dd_stripped = strip_dd(all_dd)
    # print(len(all_dd_stripped))
    all_dd_stripped = cleanup_fandom_tags(all_dd_stripped)
    all_dd_stripped = cleanup_relationship_tags(all_dd_stripped)
    all_dd_stripped = cleanup_character_tags(all_dd_stripped)
    all_dd_stripped = cleanup_additional_tags(all_dd_stripped)
    print("Successfully cleaned all_dd_stripped for link", str(i+1))

    ## create individual fanwork dictionary
    fanwork_dict = create_fanwork_dict(all_dt_updated, all_dd_stripped)
    # print(fanwork_dict)
    print("Successfully created individual fanwork dictionary for link", str(i+1))

    ## append fanwork dictionary to all_works_dict1
    append_all_works_dict(fanwork_dict, first20works_dict)
    print("Successfully appended individual fanwork dictionary", str(i+1), "to first20works_dict.")
# Out:
# Current fanwork link: 1 of 20
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to first20works_dict.
# Current fanwork link: 2 of 20
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to first20works_dict.
# Current fanwork link: 3 of 20
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to first20works_dict.
# Current fanwork link: 4 of 20
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to first20works_dict.
# Current fanwork link: 5 of 20
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to first20works_dict.
# Current fanwork link: 6 of 20
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to first20works_dict.
# Current fanwork link: 7 of 20
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to first20works_dict.
# Current fanwork link: 8 of 20
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to first20works_dict.
# Current fanwork link: 9 of 20
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to first20works_dict.
# Current fanwork link: 10 of 20
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to first20works_dict.
# Current fanwork link: 11 of 20
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to first20works_dict.
# Current fanwork link: 12 of 20
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to first20works_dict.
# Current fanwork link: 13 of 20
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to first20works_dict.
# Current fanwork link: 14 of 20
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to first20works_dict.
# Current fanwork link: 15 of 20
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to first20works_dict.
# Current fanwork link: 16 of 20
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to first20works_dict.
# Current fanwork link: 17 of 20
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to first20works_dict.
# Current fanwork link: 18 of 20
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to first20works_dict.
# Current fanwork link: 19 of 20
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to first20works_dict.
# Current fanwork link: 20 of 20
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to first20works_dict.

# %%
## convert to json and save to file
first20works_json = convert_to_json(first20works_dict)
with open('./data/first20works.json', "w") as f:
    f.write(first20works_json)

# %% [markdown]
# ## Full fanworks list

# %%
print(len(fanwork_links))
# Out:
# 211

# %%
fanwork_links_minus1 = fanwork_links[1:]

# %%
print(len(fanwork_links_minus1))
# Out:
# 210

# %%
## full fanworks list
total_fanworks = len(fanwork_links)
all_candela_works_dict = {}
for i in range(len(fanwork_links)):
    print("Current fanwork link:", str(i+1), "of", total_fanworks)

    ## load fanworks and create soup objects
    soup = get_html_doc_fanworks(fanwork_links[i])
    all_dt = get_all_dt(soup)
    all_dt_updated = update_all_dt(all_dt)
    # print(all_dt_updated)
    all_dd = get_all_dd(soup)
    print("Successfully loaded fanworks and created soup objects for link", str(i+1))

    ## clean up all_dd
    all_dd_stripped = strip_dd(all_dd)
    # print(len(all_dd_stripped))
    all_dd_stripped = cleanup_fandom_tags(all_dd_stripped)
    all_dd_stripped = cleanup_relationship_tags(all_dd_stripped)
    all_dd_stripped = cleanup_character_tags(all_dd_stripped)
    all_dd_stripped = cleanup_additional_tags(all_dd_stripped)
    print("Successfully cleaned all_dd_stripped for link", str(i+1))

    ## create individual fanwork dictionary
    fanwork_dict = create_fanwork_dict(all_dt_updated, all_dd_stripped)
    # print(fanwork_dict)
    print("Successfully created individual fanwork dictionary for link", str(i+1))

    ## append fanwork dictionary to all_works_dict1
    append_all_works_dict(fanwork_dict, all_candela_works_dict)
    print("Successfully appended individual fanwork dictionary", str(i+1), "to all_candela_works_dict.")
# Out:
# Current fanwork link: 1 of 210
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to all_candela_works_dict.
# Current fanwork link: 2 of 210
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to all_candela_works_dict.
# Current fanwork link: 3 of 210
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to all_candela_works_dict.
# Current fanwork link: 4 of 210
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to all_candela_works_dict.
# Current fanwork link: 5 of 210
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to all_candela_works_dict.
# Current fanwork link: 6 of 210
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to all_candela_works_dict.
# Current fanwork link: 7 of 210
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to all_candela_works_dict.
# Current fanwork link: 8 of 210
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to all_candela_works_dict.
# Current fanwork link: 9 of 210
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to all_candela_works_dict.
# Current fanwork link: 10 of 210
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to all_candela_works_dict.
# Current fanwork link: 11 of 210
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to all_candela_works_dict.
# Current fanwork link: 12 of 210
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to all_candela_works_dict.
# Current fanwork link: 13 of 210
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to all_candela_works_dict.
# Current fanwork link: 14 of 210
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to all_candela_works_dict.
# Current fanwork link: 15 of 210
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to all_candela_works_dict.
# Current fanwork link: 16 of 210
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to all_candela_works_dict.
# Current fanwork link: 17 of 210
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to all_candela_works_dict.
# Current fanwork link: 18 of 210
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to all_candela_works_dict.
# Current fanwork link: 19 of 210
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to all_candela_works_dict.
# Current fanwork link: 20 of 210
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to all_candela_works_dict.
# Current fanwork link: 21 of 210
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to all_candela_works_dict.
# Current fanwork link: 22 of 210
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to all_candela_works_dict.
# Current fanwork link: 23 of 210
# Successfully loaded fanworks and created soup objects for link 23
# Successfully cleaned all_dd_stripped for link 23
# Successfully created individual fanwork dictionary for link 23
# Successfully appended individual fanwork dictionary 23 to all_candela_works_dict.
# Current fanwork link: 24 of 210
# Successfully loaded fanworks and created soup objects for link 24
# Successfully cleaned all_dd_stripped for link 24
# Successfully created individual fanwork dictionary for link 24
# Successfully appended individual fanwork dictionary 24 to all_candela_works_dict.
# Current fanwork link: 25 of 210
# Successfully loaded fanworks and created soup objects for link 25
# Successfully cleaned all_dd_stripped for link 25
# Successfully created individual fanwork dictionary for link 25
# Successfully appended individual fanwork dictionary 25 to all_candela_works_dict.
# Current fanwork link: 26 of 210
# Successfully loaded fanworks and created soup objects for link 26
# Successfully cleaned all_dd_stripped for link 26
# Successfully created individual fanwork dictionary for link 26
# Successfully appended individual fanwork dictionary 26 to all_candela_works_dict.
# Current fanwork link: 27 of 210
# Successfully loaded fanworks and created soup objects for link 27
# Successfully cleaned all_dd_stripped for link 27
# Successfully created individual fanwork dictionary for link 27
# Successfully appended individual fanwork dictionary 27 to all_candela_works_dict.
# Current fanwork link: 28 of 210
# Successfully loaded fanworks and created soup objects for link 28
# Successfully cleaned all_dd_stripped for link 28
# Successfully created individual fanwork dictionary for link 28
# Successfully appended individual fanwork dictionary 28 to all_candela_works_dict.
# Current fanwork link: 29 of 210
# Successfully loaded fanworks and created soup objects for link 29
# Successfully cleaned all_dd_stripped for link 29
# Successfully created individual fanwork dictionary for link 29
# Successfully appended individual fanwork dictionary 29 to all_candela_works_dict.
# Current fanwork link: 30 of 210
# Successfully loaded fanworks and created soup objects for link 30
# Successfully cleaned all_dd_stripped for link 30
# Successfully created individual fanwork dictionary for link 30
# Successfully appended individual fanwork dictionary 30 to all_candela_works_dict.
# Current fanwork link: 31 of 210
# Successfully loaded fanworks and created soup objects for link 31
# Successfully cleaned all_dd_stripped for link 31
# Successfully created individual fanwork dictionary for link 31
# Successfully appended individual fanwork dictionary 31 to all_candela_works_dict.
# Current fanwork link: 32 of 210
# Successfully loaded fanworks and created soup objects for link 32
# Successfully cleaned all_dd_stripped for link 32
# Successfully created individual fanwork dictionary for link 32
# Successfully appended individual fanwork dictionary 32 to all_candela_works_dict.
# Current fanwork link: 33 of 210
# Successfully loaded fanworks and created soup objects for link 33
# Successfully cleaned all_dd_stripped for link 33
# Successfully created individual fanwork dictionary for link 33
# Successfully appended individual fanwork dictionary 33 to all_candela_works_dict.
# Current fanwork link: 34 of 210
# Successfully loaded fanworks and created soup objects for link 34
# Successfully cleaned all_dd_stripped for link 34
# Successfully created individual fanwork dictionary for link 34
# Successfully appended individual fanwork dictionary 34 to all_candela_works_dict.
# Current fanwork link: 35 of 210
# Successfully loaded fanworks and created soup objects for link 35
# Successfully cleaned all_dd_stripped for link 35
# Successfully created individual fanwork dictionary for link 35
# Successfully appended individual fanwork dictionary 35 to all_candela_works_dict.
# Current fanwork link: 36 of 210
# Successfully loaded fanworks and created soup objects for link 36
# Successfully cleaned all_dd_stripped for link 36
# Successfully created individual fanwork dictionary for link 36
# Successfully appended individual fanwork dictionary 36 to all_candela_works_dict.
# Current fanwork link: 37 of 210
# Successfully loaded fanworks and created soup objects for link 37
# Successfully cleaned all_dd_stripped for link 37
# Successfully created individual fanwork dictionary for link 37
# Successfully appended individual fanwork dictionary 37 to all_candela_works_dict.
# Current fanwork link: 38 of 210
# Successfully loaded fanworks and created soup objects for link 38
# Successfully cleaned all_dd_stripped for link 38
# Successfully created individual fanwork dictionary for link 38
# Successfully appended individual fanwork dictionary 38 to all_candela_works_dict.
# Current fanwork link: 39 of 210
# Successfully loaded fanworks and created soup objects for link 39
# Successfully cleaned all_dd_stripped for link 39
# Successfully created individual fanwork dictionary for link 39
# Successfully appended individual fanwork dictionary 39 to all_candela_works_dict.
# Current fanwork link: 40 of 210
# Successfully loaded fanworks and created soup objects for link 40
# Successfully cleaned all_dd_stripped for link 40
# Successfully created individual fanwork dictionary for link 40
# Successfully appended individual fanwork dictionary 40 to all_candela_works_dict.
# Current fanwork link: 41 of 210
# Successfully loaded fanworks and created soup objects for link 41
# Successfully cleaned all_dd_stripped for link 41
# Successfully created individual fanwork dictionary for link 41
# Successfully appended individual fanwork dictionary 41 to all_candela_works_dict.
# Current fanwork link: 42 of 210
# Successfully loaded fanworks and created soup objects for link 42
# Successfully cleaned all_dd_stripped for link 42
# Successfully created individual fanwork dictionary for link 42
# Successfully appended individual fanwork dictionary 42 to all_candela_works_dict.
# Current fanwork link: 43 of 210
# Successfully loaded fanworks and created soup objects for link 43
# Successfully cleaned all_dd_stripped for link 43
# Successfully created individual fanwork dictionary for link 43
# Successfully appended individual fanwork dictionary 43 to all_candela_works_dict.
# Current fanwork link: 44 of 210
# Successfully loaded fanworks and created soup objects for link 44
# Successfully cleaned all_dd_stripped for link 44
# Successfully created individual fanwork dictionary for link 44
# Successfully appended individual fanwork dictionary 44 to all_candela_works_dict.
# Current fanwork link: 45 of 210
# Successfully loaded fanworks and created soup objects for link 45
# Successfully cleaned all_dd_stripped for link 45
# Successfully created individual fanwork dictionary for link 45
# Successfully appended individual fanwork dictionary 45 to all_candela_works_dict.
# Current fanwork link: 46 of 210
# Successfully loaded fanworks and created soup objects for link 46
# Successfully cleaned all_dd_stripped for link 46
# Successfully created individual fanwork dictionary for link 46
# Successfully appended individual fanwork dictionary 46 to all_candela_works_dict.
# Current fanwork link: 47 of 210
# Successfully loaded fanworks and created soup objects for link 47
# Successfully cleaned all_dd_stripped for link 47
# Successfully created individual fanwork dictionary for link 47
# Successfully appended individual fanwork dictionary 47 to all_candela_works_dict.
# Current fanwork link: 48 of 210
# Successfully loaded fanworks and created soup objects for link 48
# Successfully cleaned all_dd_stripped for link 48
# Successfully created individual fanwork dictionary for link 48
# Successfully appended individual fanwork dictionary 48 to all_candela_works_dict.
# Current fanwork link: 49 of 210
# Successfully loaded fanworks and created soup objects for link 49
# Successfully cleaned all_dd_stripped for link 49
# Successfully created individual fanwork dictionary for link 49
# Successfully appended individual fanwork dictionary 49 to all_candela_works_dict.
# Current fanwork link: 50 of 210
# Successfully loaded fanworks and created soup objects for link 50
# Successfully cleaned all_dd_stripped for link 50
# Successfully created individual fanwork dictionary for link 50
# Successfully appended individual fanwork dictionary 50 to all_candela_works_dict.
# Current fanwork link: 51 of 210
# Successfully loaded fanworks and created soup objects for link 51
# Successfully cleaned all_dd_stripped for link 51
# Successfully created individual fanwork dictionary for link 51
# Successfully appended individual fanwork dictionary 51 to all_candela_works_dict.
# Current fanwork link: 52 of 210
# Successfully loaded fanworks and created soup objects for link 52
# Successfully cleaned all_dd_stripped for link 52
# Successfully created individual fanwork dictionary for link 52
# Successfully appended individual fanwork dictionary 52 to all_candela_works_dict.
# Current fanwork link: 53 of 210
# Successfully loaded fanworks and created soup objects for link 53
# Successfully cleaned all_dd_stripped for link 53
# Successfully created individual fanwork dictionary for link 53
# Successfully appended individual fanwork dictionary 53 to all_candela_works_dict.
# Current fanwork link: 54 of 210
# Successfully loaded fanworks and created soup objects for link 54
# Successfully cleaned all_dd_stripped for link 54
# Successfully created individual fanwork dictionary for link 54
# Successfully appended individual fanwork dictionary 54 to all_candela_works_dict.
# Current fanwork link: 55 of 210
# Successfully loaded fanworks and created soup objects for link 55
# Successfully cleaned all_dd_stripped for link 55
# Successfully created individual fanwork dictionary for link 55
# Successfully appended individual fanwork dictionary 55 to all_candela_works_dict.
# Current fanwork link: 56 of 210
# Successfully loaded fanworks and created soup objects for link 56
# Successfully cleaned all_dd_stripped for link 56
# Successfully created individual fanwork dictionary for link 56
# Successfully appended individual fanwork dictionary 56 to all_candela_works_dict.
# Current fanwork link: 57 of 210
# Successfully loaded fanworks and created soup objects for link 57
# Successfully cleaned all_dd_stripped for link 57
# Successfully created individual fanwork dictionary for link 57
# Successfully appended individual fanwork dictionary 57 to all_candela_works_dict.
# Current fanwork link: 58 of 210
# Successfully loaded fanworks and created soup objects for link 58
# Successfully cleaned all_dd_stripped for link 58
# Successfully created individual fanwork dictionary for link 58
# Successfully appended individual fanwork dictionary 58 to all_candela_works_dict.
# Current fanwork link: 59 of 210
# Successfully loaded fanworks and created soup objects for link 59
# Successfully cleaned all_dd_stripped for link 59
# Successfully created individual fanwork dictionary for link 59
# Successfully appended individual fanwork dictionary 59 to all_candela_works_dict.
# Current fanwork link: 60 of 210
# Successfully loaded fanworks and created soup objects for link 60
# Successfully cleaned all_dd_stripped for link 60
# Successfully created individual fanwork dictionary for link 60
# Successfully appended individual fanwork dictionary 60 to all_candela_works_dict.
# Current fanwork link: 61 of 210
# Successfully loaded fanworks and created soup objects for link 61
# Successfully cleaned all_dd_stripped for link 61
# Successfully created individual fanwork dictionary for link 61
# Successfully appended individual fanwork dictionary 61 to all_candela_works_dict.
# Current fanwork link: 62 of 210
# Successfully loaded fanworks and created soup objects for link 62
# Successfully cleaned all_dd_stripped for link 62
# Successfully created individual fanwork dictionary for link 62
# Successfully appended individual fanwork dictionary 62 to all_candela_works_dict.
# Current fanwork link: 63 of 210
# Successfully loaded fanworks and created soup objects for link 63
# Successfully cleaned all_dd_stripped for link 63
# Successfully created individual fanwork dictionary for link 63
# Successfully appended individual fanwork dictionary 63 to all_candela_works_dict.
# Current fanwork link: 64 of 210
# Successfully loaded fanworks and created soup objects for link 64
# Successfully cleaned all_dd_stripped for link 64
# Successfully created individual fanwork dictionary for link 64
# Successfully appended individual fanwork dictionary 64 to all_candela_works_dict.
# Current fanwork link: 65 of 210
# Successfully loaded fanworks and created soup objects for link 65
# Successfully cleaned all_dd_stripped for link 65
# Successfully created individual fanwork dictionary for link 65
# Successfully appended individual fanwork dictionary 65 to all_candela_works_dict.
# Current fanwork link: 66 of 210
# Successfully loaded fanworks and created soup objects for link 66
# Successfully cleaned all_dd_stripped for link 66
# Successfully created individual fanwork dictionary for link 66
# Successfully appended individual fanwork dictionary 66 to all_candela_works_dict.
# Current fanwork link: 67 of 210
# Successfully loaded fanworks and created soup objects for link 67
# Successfully cleaned all_dd_stripped for link 67
# Successfully created individual fanwork dictionary for link 67
# Successfully appended individual fanwork dictionary 67 to all_candela_works_dict.
# Current fanwork link: 68 of 210
# Successfully loaded fanworks and created soup objects for link 68
# Successfully cleaned all_dd_stripped for link 68
# Successfully created individual fanwork dictionary for link 68
# Successfully appended individual fanwork dictionary 68 to all_candela_works_dict.
# Current fanwork link: 69 of 210
# Successfully loaded fanworks and created soup objects for link 69
# Successfully cleaned all_dd_stripped for link 69
# Successfully created individual fanwork dictionary for link 69
# Successfully appended individual fanwork dictionary 69 to all_candela_works_dict.
# Current fanwork link: 70 of 210
# Successfully loaded fanworks and created soup objects for link 70
# Successfully cleaned all_dd_stripped for link 70
# Successfully created individual fanwork dictionary for link 70
# Successfully appended individual fanwork dictionary 70 to all_candela_works_dict.
# Current fanwork link: 71 of 210
# Successfully loaded fanworks and created soup objects for link 71
# Successfully cleaned all_dd_stripped for link 71
# Successfully created individual fanwork dictionary for link 71
# Successfully appended individual fanwork dictionary 71 to all_candela_works_dict.
# Current fanwork link: 72 of 210
# Successfully loaded fanworks and created soup objects for link 72
# Successfully cleaned all_dd_stripped for link 72
# Successfully created individual fanwork dictionary for link 72
# Successfully appended individual fanwork dictionary 72 to all_candela_works_dict.
# Current fanwork link: 73 of 210
# Successfully loaded fanworks and created soup objects for link 73
# Successfully cleaned all_dd_stripped for link 73
# Successfully created individual fanwork dictionary for link 73
# Successfully appended individual fanwork dictionary 73 to all_candela_works_dict.
# Current fanwork link: 74 of 210
# Successfully loaded fanworks and created soup objects for link 74
# Successfully cleaned all_dd_stripped for link 74
# Successfully created individual fanwork dictionary for link 74
# Successfully appended individual fanwork dictionary 74 to all_candela_works_dict.
# Current fanwork link: 75 of 210
# Successfully loaded fanworks and created soup objects for link 75
# Successfully cleaned all_dd_stripped for link 75
# Successfully created individual fanwork dictionary for link 75
# Successfully appended individual fanwork dictionary 75 to all_candela_works_dict.
# Current fanwork link: 76 of 210
# Successfully loaded fanworks and created soup objects for link 76
# Successfully cleaned all_dd_stripped for link 76
# Successfully created individual fanwork dictionary for link 76
# Successfully appended individual fanwork dictionary 76 to all_candela_works_dict.
# Current fanwork link: 77 of 210
# Successfully loaded fanworks and created soup objects for link 77
# Successfully cleaned all_dd_stripped for link 77
# Successfully created individual fanwork dictionary for link 77
# Successfully appended individual fanwork dictionary 77 to all_candela_works_dict.
# Current fanwork link: 78 of 210
# Successfully loaded fanworks and created soup objects for link 78
# Successfully cleaned all_dd_stripped for link 78
# Successfully created individual fanwork dictionary for link 78
# Successfully appended individual fanwork dictionary 78 to all_candela_works_dict.
# Current fanwork link: 79 of 210
# Successfully loaded fanworks and created soup objects for link 79
# Successfully cleaned all_dd_stripped for link 79
# Successfully created individual fanwork dictionary for link 79
# Successfully appended individual fanwork dictionary 79 to all_candela_works_dict.
# Current fanwork link: 80 of 210
# Successfully loaded fanworks and created soup objects for link 80
# Successfully cleaned all_dd_stripped for link 80
# Successfully created individual fanwork dictionary for link 80
# Successfully appended individual fanwork dictionary 80 to all_candela_works_dict.
# Current fanwork link: 81 of 210
# Successfully loaded fanworks and created soup objects for link 81
# Successfully cleaned all_dd_stripped for link 81
# Successfully created individual fanwork dictionary for link 81
# Successfully appended individual fanwork dictionary 81 to all_candela_works_dict.
# Current fanwork link: 82 of 210
# Successfully loaded fanworks and created soup objects for link 82
# Successfully cleaned all_dd_stripped for link 82
# Successfully created individual fanwork dictionary for link 82
# Successfully appended individual fanwork dictionary 82 to all_candela_works_dict.
# Current fanwork link: 83 of 210
# Successfully loaded fanworks and created soup objects for link 83
# Successfully cleaned all_dd_stripped for link 83
# Successfully created individual fanwork dictionary for link 83
# Successfully appended individual fanwork dictionary 83 to all_candela_works_dict.
# Current fanwork link: 84 of 210
# Successfully loaded fanworks and created soup objects for link 84
# Successfully cleaned all_dd_stripped for link 84
# Successfully created individual fanwork dictionary for link 84
# Successfully appended individual fanwork dictionary 84 to all_candela_works_dict.
# Current fanwork link: 85 of 210
# Successfully loaded fanworks and created soup objects for link 85
# Successfully cleaned all_dd_stripped for link 85
# Successfully created individual fanwork dictionary for link 85
# Successfully appended individual fanwork dictionary 85 to all_candela_works_dict.
# Current fanwork link: 86 of 210
# Successfully loaded fanworks and created soup objects for link 86
# Successfully cleaned all_dd_stripped for link 86
# Successfully created individual fanwork dictionary for link 86
# Successfully appended individual fanwork dictionary 86 to all_candela_works_dict.
# Current fanwork link: 87 of 210
# Successfully loaded fanworks and created soup objects for link 87
# Successfully cleaned all_dd_stripped for link 87
# Successfully created individual fanwork dictionary for link 87
# Successfully appended individual fanwork dictionary 87 to all_candela_works_dict.
# Current fanwork link: 88 of 210
# Successfully loaded fanworks and created soup objects for link 88
# Successfully cleaned all_dd_stripped for link 88
# Successfully created individual fanwork dictionary for link 88
# Successfully appended individual fanwork dictionary 88 to all_candela_works_dict.
# Current fanwork link: 89 of 210
# Successfully loaded fanworks and created soup objects for link 89
# Successfully cleaned all_dd_stripped for link 89
# Successfully created individual fanwork dictionary for link 89
# Successfully appended individual fanwork dictionary 89 to all_candela_works_dict.
# Current fanwork link: 90 of 210
# Successfully loaded fanworks and created soup objects for link 90
# Successfully cleaned all_dd_stripped for link 90
# Successfully created individual fanwork dictionary for link 90
# Successfully appended individual fanwork dictionary 90 to all_candela_works_dict.
# Current fanwork link: 91 of 210
# Successfully loaded fanworks and created soup objects for link 91
# Successfully cleaned all_dd_stripped for link 91
# Successfully created individual fanwork dictionary for link 91
# Successfully appended individual fanwork dictionary 91 to all_candela_works_dict.
# Current fanwork link: 92 of 210
# Successfully loaded fanworks and created soup objects for link 92
# Successfully cleaned all_dd_stripped for link 92
# Successfully created individual fanwork dictionary for link 92
# Successfully appended individual fanwork dictionary 92 to all_candela_works_dict.
# Current fanwork link: 93 of 210
# Successfully loaded fanworks and created soup objects for link 93
# Successfully cleaned all_dd_stripped for link 93
# Successfully created individual fanwork dictionary for link 93
# Successfully appended individual fanwork dictionary 93 to all_candela_works_dict.
# Current fanwork link: 94 of 210
# Successfully loaded fanworks and created soup objects for link 94
# Successfully cleaned all_dd_stripped for link 94
# Successfully created individual fanwork dictionary for link 94
# Successfully appended individual fanwork dictionary 94 to all_candela_works_dict.
# Current fanwork link: 95 of 210
# Successfully loaded fanworks and created soup objects for link 95
# Successfully cleaned all_dd_stripped for link 95
# Successfully created individual fanwork dictionary for link 95
# Successfully appended individual fanwork dictionary 95 to all_candela_works_dict.
# Current fanwork link: 96 of 210
# Successfully loaded fanworks and created soup objects for link 96
# Successfully cleaned all_dd_stripped for link 96
# Successfully created individual fanwork dictionary for link 96
# Successfully appended individual fanwork dictionary 96 to all_candela_works_dict.
# Current fanwork link: 97 of 210
# Successfully loaded fanworks and created soup objects for link 97
# Successfully cleaned all_dd_stripped for link 97
# Successfully created individual fanwork dictionary for link 97
# Successfully appended individual fanwork dictionary 97 to all_candela_works_dict.
# Current fanwork link: 98 of 210
# Successfully loaded fanworks and created soup objects for link 98
# Successfully cleaned all_dd_stripped for link 98
# Successfully created individual fanwork dictionary for link 98
# Successfully appended individual fanwork dictionary 98 to all_candela_works_dict.
# Current fanwork link: 99 of 210
# Successfully loaded fanworks and created soup objects for link 99
# Successfully cleaned all_dd_stripped for link 99
# Successfully created individual fanwork dictionary for link 99
# Successfully appended individual fanwork dictionary 99 to all_candela_works_dict.
# Current fanwork link: 100 of 210
# Successfully loaded fanworks and created soup objects for link 100
# Successfully cleaned all_dd_stripped for link 100
# Successfully created individual fanwork dictionary for link 100
# Successfully appended individual fanwork dictionary 100 to all_candela_works_dict.
# Current fanwork link: 101 of 210
# Successfully loaded fanworks and created soup objects for link 101
# Successfully cleaned all_dd_stripped for link 101
# Successfully created individual fanwork dictionary for link 101
# Successfully appended individual fanwork dictionary 101 to all_candela_works_dict.
# Current fanwork link: 102 of 210
# Successfully loaded fanworks and created soup objects for link 102
# Successfully cleaned all_dd_stripped for link 102
# Successfully created individual fanwork dictionary for link 102
# Successfully appended individual fanwork dictionary 102 to all_candela_works_dict.
# Current fanwork link: 103 of 210
# Successfully loaded fanworks and created soup objects for link 103
# Successfully cleaned all_dd_stripped for link 103
# Successfully created individual fanwork dictionary for link 103
# Successfully appended individual fanwork dictionary 103 to all_candela_works_dict.
# Current fanwork link: 104 of 210
# Successfully loaded fanworks and created soup objects for link 104
# Successfully cleaned all_dd_stripped for link 104
# Successfully created individual fanwork dictionary for link 104
# Successfully appended individual fanwork dictionary 104 to all_candela_works_dict.
# Current fanwork link: 105 of 210
# Successfully loaded fanworks and created soup objects for link 105
# Successfully cleaned all_dd_stripped for link 105
# Successfully created individual fanwork dictionary for link 105
# Successfully appended individual fanwork dictionary 105 to all_candela_works_dict.
# Current fanwork link: 106 of 210
# Successfully loaded fanworks and created soup objects for link 106
# Successfully cleaned all_dd_stripped for link 106
# Successfully created individual fanwork dictionary for link 106
# Successfully appended individual fanwork dictionary 106 to all_candela_works_dict.
# Current fanwork link: 107 of 210
# Successfully loaded fanworks and created soup objects for link 107
# Successfully cleaned all_dd_stripped for link 107
# Successfully created individual fanwork dictionary for link 107
# Successfully appended individual fanwork dictionary 107 to all_candela_works_dict.
# Current fanwork link: 108 of 210
# Successfully loaded fanworks and created soup objects for link 108
# Successfully cleaned all_dd_stripped for link 108
# Successfully created individual fanwork dictionary for link 108
# Successfully appended individual fanwork dictionary 108 to all_candela_works_dict.
# Current fanwork link: 109 of 210
# Successfully loaded fanworks and created soup objects for link 109
# Successfully cleaned all_dd_stripped for link 109
# Successfully created individual fanwork dictionary for link 109
# Successfully appended individual fanwork dictionary 109 to all_candela_works_dict.
# Current fanwork link: 110 of 210
# Successfully loaded fanworks and created soup objects for link 110
# Successfully cleaned all_dd_stripped for link 110
# Successfully created individual fanwork dictionary for link 110
# Successfully appended individual fanwork dictionary 110 to all_candela_works_dict.
# Current fanwork link: 111 of 210
# Successfully loaded fanworks and created soup objects for link 111
# Successfully cleaned all_dd_stripped for link 111
# Successfully created individual fanwork dictionary for link 111
# Successfully appended individual fanwork dictionary 111 to all_candela_works_dict.
# Current fanwork link: 112 of 210
# Successfully loaded fanworks and created soup objects for link 112
# Successfully cleaned all_dd_stripped for link 112
# Successfully created individual fanwork dictionary for link 112
# Successfully appended individual fanwork dictionary 112 to all_candela_works_dict.
# Current fanwork link: 113 of 210
# Successfully loaded fanworks and created soup objects for link 113
# Successfully cleaned all_dd_stripped for link 113
# Successfully created individual fanwork dictionary for link 113
# Successfully appended individual fanwork dictionary 113 to all_candela_works_dict.
# Current fanwork link: 114 of 210
# Successfully loaded fanworks and created soup objects for link 114
# Successfully cleaned all_dd_stripped for link 114
# Successfully created individual fanwork dictionary for link 114
# Successfully appended individual fanwork dictionary 114 to all_candela_works_dict.
# Current fanwork link: 115 of 210
# Successfully loaded fanworks and created soup objects for link 115
# Successfully cleaned all_dd_stripped for link 115
# Successfully created individual fanwork dictionary for link 115
# Successfully appended individual fanwork dictionary 115 to all_candela_works_dict.
# Current fanwork link: 116 of 210
# Successfully loaded fanworks and created soup objects for link 116
# Successfully cleaned all_dd_stripped for link 116
# Successfully created individual fanwork dictionary for link 116
# Successfully appended individual fanwork dictionary 116 to all_candela_works_dict.
# Current fanwork link: 117 of 210
# Successfully loaded fanworks and created soup objects for link 117
# Successfully cleaned all_dd_stripped for link 117
# Successfully created individual fanwork dictionary for link 117
# Successfully appended individual fanwork dictionary 117 to all_candela_works_dict.
# Current fanwork link: 118 of 210
# Successfully loaded fanworks and created soup objects for link 118
# Successfully cleaned all_dd_stripped for link 118
# Successfully created individual fanwork dictionary for link 118
# Successfully appended individual fanwork dictionary 118 to all_candela_works_dict.
# Current fanwork link: 119 of 210
# Successfully loaded fanworks and created soup objects for link 119
# Successfully cleaned all_dd_stripped for link 119
# Successfully created individual fanwork dictionary for link 119
# Successfully appended individual fanwork dictionary 119 to all_candela_works_dict.
# Current fanwork link: 120 of 210
# Successfully loaded fanworks and created soup objects for link 120
# Successfully cleaned all_dd_stripped for link 120
# Successfully created individual fanwork dictionary for link 120
# Successfully appended individual fanwork dictionary 120 to all_candela_works_dict.
# Current fanwork link: 121 of 210
# Successfully loaded fanworks and created soup objects for link 121
# Successfully cleaned all_dd_stripped for link 121
# Successfully created individual fanwork dictionary for link 121
# Successfully appended individual fanwork dictionary 121 to all_candela_works_dict.
# Current fanwork link: 122 of 210
# Successfully loaded fanworks and created soup objects for link 122
# Successfully cleaned all_dd_stripped for link 122
# Successfully created individual fanwork dictionary for link 122
# Successfully appended individual fanwork dictionary 122 to all_candela_works_dict.
# Current fanwork link: 123 of 210
# Successfully loaded fanworks and created soup objects for link 123
# Successfully cleaned all_dd_stripped for link 123
# Successfully created individual fanwork dictionary for link 123
# Successfully appended individual fanwork dictionary 123 to all_candela_works_dict.
# Current fanwork link: 124 of 210
# Successfully loaded fanworks and created soup objects for link 124
# Successfully cleaned all_dd_stripped for link 124
# Successfully created individual fanwork dictionary for link 124
# Successfully appended individual fanwork dictionary 124 to all_candela_works_dict.
# Current fanwork link: 125 of 210
# Successfully loaded fanworks and created soup objects for link 125
# Successfully cleaned all_dd_stripped for link 125
# Successfully created individual fanwork dictionary for link 125
# Successfully appended individual fanwork dictionary 125 to all_candela_works_dict.
# Current fanwork link: 126 of 210
# Successfully loaded fanworks and created soup objects for link 126
# Successfully cleaned all_dd_stripped for link 126
# Successfully created individual fanwork dictionary for link 126
# Successfully appended individual fanwork dictionary 126 to all_candela_works_dict.
# Current fanwork link: 127 of 210
# Successfully loaded fanworks and created soup objects for link 127
# Successfully cleaned all_dd_stripped for link 127
# Successfully created individual fanwork dictionary for link 127
# Successfully appended individual fanwork dictionary 127 to all_candela_works_dict.
# Current fanwork link: 128 of 210
# Successfully loaded fanworks and created soup objects for link 128
# Successfully cleaned all_dd_stripped for link 128
# Successfully created individual fanwork dictionary for link 128
# Successfully appended individual fanwork dictionary 128 to all_candela_works_dict.
# Current fanwork link: 129 of 210
# Successfully loaded fanworks and created soup objects for link 129
# Successfully cleaned all_dd_stripped for link 129
# Successfully created individual fanwork dictionary for link 129
# Successfully appended individual fanwork dictionary 129 to all_candela_works_dict.
# Current fanwork link: 130 of 210
# Successfully loaded fanworks and created soup objects for link 130
# Successfully cleaned all_dd_stripped for link 130
# Successfully created individual fanwork dictionary for link 130
# Successfully appended individual fanwork dictionary 130 to all_candela_works_dict.
# Current fanwork link: 131 of 210
# Successfully loaded fanworks and created soup objects for link 131
# Successfully cleaned all_dd_stripped for link 131
# Successfully created individual fanwork dictionary for link 131
# Successfully appended individual fanwork dictionary 131 to all_candela_works_dict.
# Current fanwork link: 132 of 210
# Successfully loaded fanworks and created soup objects for link 132
# Successfully cleaned all_dd_stripped for link 132
# Successfully created individual fanwork dictionary for link 132
# Successfully appended individual fanwork dictionary 132 to all_candela_works_dict.
# Current fanwork link: 133 of 210
# Successfully loaded fanworks and created soup objects for link 133
# Successfully cleaned all_dd_stripped for link 133
# Successfully created individual fanwork dictionary for link 133
# Successfully appended individual fanwork dictionary 133 to all_candela_works_dict.
# Current fanwork link: 134 of 210
# Successfully loaded fanworks and created soup objects for link 134
# Successfully cleaned all_dd_stripped for link 134
# Successfully created individual fanwork dictionary for link 134
# Successfully appended individual fanwork dictionary 134 to all_candela_works_dict.
# Current fanwork link: 135 of 210
# Successfully loaded fanworks and created soup objects for link 135
# Successfully cleaned all_dd_stripped for link 135
# Successfully created individual fanwork dictionary for link 135
# Successfully appended individual fanwork dictionary 135 to all_candela_works_dict.
# Current fanwork link: 136 of 210
# Successfully loaded fanworks and created soup objects for link 136
# Successfully cleaned all_dd_stripped for link 136
# Successfully created individual fanwork dictionary for link 136
# Successfully appended individual fanwork dictionary 136 to all_candela_works_dict.
# Current fanwork link: 137 of 210
# Successfully loaded fanworks and created soup objects for link 137
# Successfully cleaned all_dd_stripped for link 137
# Successfully created individual fanwork dictionary for link 137
# Successfully appended individual fanwork dictionary 137 to all_candela_works_dict.
# Current fanwork link: 138 of 210
# Successfully loaded fanworks and created soup objects for link 138
# Successfully cleaned all_dd_stripped for link 138
# Successfully created individual fanwork dictionary for link 138
# Successfully appended individual fanwork dictionary 138 to all_candela_works_dict.
# Current fanwork link: 139 of 210
# Successfully loaded fanworks and created soup objects for link 139
# Successfully cleaned all_dd_stripped for link 139
# Successfully created individual fanwork dictionary for link 139
# Successfully appended individual fanwork dictionary 139 to all_candela_works_dict.
# Current fanwork link: 140 of 210
# Successfully loaded fanworks and created soup objects for link 140
# Successfully cleaned all_dd_stripped for link 140
# Successfully created individual fanwork dictionary for link 140
# Successfully appended individual fanwork dictionary 140 to all_candela_works_dict.
# Current fanwork link: 141 of 210
# Successfully loaded fanworks and created soup objects for link 141
# Successfully cleaned all_dd_stripped for link 141
# Successfully created individual fanwork dictionary for link 141
# Successfully appended individual fanwork dictionary 141 to all_candela_works_dict.
# Current fanwork link: 142 of 210
# Successfully loaded fanworks and created soup objects for link 142
# Successfully cleaned all_dd_stripped for link 142
# Successfully created individual fanwork dictionary for link 142
# Successfully appended individual fanwork dictionary 142 to all_candela_works_dict.
# Current fanwork link: 143 of 210
# Successfully loaded fanworks and created soup objects for link 143
# Successfully cleaned all_dd_stripped for link 143
# Successfully created individual fanwork dictionary for link 143
# Successfully appended individual fanwork dictionary 143 to all_candela_works_dict.
# Current fanwork link: 144 of 210
# Successfully loaded fanworks and created soup objects for link 144
# Successfully cleaned all_dd_stripped for link 144
# Successfully created individual fanwork dictionary for link 144
# Successfully appended individual fanwork dictionary 144 to all_candela_works_dict.
# Current fanwork link: 145 of 210
# Successfully loaded fanworks and created soup objects for link 145
# Successfully cleaned all_dd_stripped for link 145
# Successfully created individual fanwork dictionary for link 145
# Successfully appended individual fanwork dictionary 145 to all_candela_works_dict.
# Current fanwork link: 146 of 210
# Successfully loaded fanworks and created soup objects for link 146
# Successfully cleaned all_dd_stripped for link 146
# Successfully created individual fanwork dictionary for link 146
# Successfully appended individual fanwork dictionary 146 to all_candela_works_dict.
# Current fanwork link: 147 of 210
# Successfully loaded fanworks and created soup objects for link 147
# Successfully cleaned all_dd_stripped for link 147
# Successfully created individual fanwork dictionary for link 147
# Successfully appended individual fanwork dictionary 147 to all_candela_works_dict.
# Current fanwork link: 148 of 210
# Successfully loaded fanworks and created soup objects for link 148
# Successfully cleaned all_dd_stripped for link 148
# Successfully created individual fanwork dictionary for link 148
# Successfully appended individual fanwork dictionary 148 to all_candela_works_dict.
# Current fanwork link: 149 of 210
# Successfully loaded fanworks and created soup objects for link 149
# Successfully cleaned all_dd_stripped for link 149
# Successfully created individual fanwork dictionary for link 149
# Successfully appended individual fanwork dictionary 149 to all_candela_works_dict.
# Current fanwork link: 150 of 210
# Successfully loaded fanworks and created soup objects for link 150
# Successfully cleaned all_dd_stripped for link 150
# Successfully created individual fanwork dictionary for link 150
# Successfully appended individual fanwork dictionary 150 to all_candela_works_dict.
# Current fanwork link: 151 of 210
# Successfully loaded fanworks and created soup objects for link 151
# Successfully cleaned all_dd_stripped for link 151
# Successfully created individual fanwork dictionary for link 151
# Successfully appended individual fanwork dictionary 151 to all_candela_works_dict.
# Current fanwork link: 152 of 210
# Successfully loaded fanworks and created soup objects for link 152
# Successfully cleaned all_dd_stripped for link 152
# Successfully created individual fanwork dictionary for link 152
# Successfully appended individual fanwork dictionary 152 to all_candela_works_dict.
# Current fanwork link: 153 of 210
# Successfully loaded fanworks and created soup objects for link 153
# Successfully cleaned all_dd_stripped for link 153
# Successfully created individual fanwork dictionary for link 153
# Successfully appended individual fanwork dictionary 153 to all_candela_works_dict.
# Current fanwork link: 154 of 210
# Successfully loaded fanworks and created soup objects for link 154
# Successfully cleaned all_dd_stripped for link 154
# Successfully created individual fanwork dictionary for link 154
# Successfully appended individual fanwork dictionary 154 to all_candela_works_dict.
# Current fanwork link: 155 of 210
# Successfully loaded fanworks and created soup objects for link 155
# Successfully cleaned all_dd_stripped for link 155
# Successfully created individual fanwork dictionary for link 155
# Successfully appended individual fanwork dictionary 155 to all_candela_works_dict.
# Current fanwork link: 156 of 210
# Successfully loaded fanworks and created soup objects for link 156
# Successfully cleaned all_dd_stripped for link 156
# Successfully created individual fanwork dictionary for link 156
# Successfully appended individual fanwork dictionary 156 to all_candela_works_dict.
# Current fanwork link: 157 of 210
# Successfully loaded fanworks and created soup objects for link 157
# Successfully cleaned all_dd_stripped for link 157
# Successfully created individual fanwork dictionary for link 157
# Successfully appended individual fanwork dictionary 157 to all_candela_works_dict.
# Current fanwork link: 158 of 210
# Successfully loaded fanworks and created soup objects for link 158
# Successfully cleaned all_dd_stripped for link 158
# Successfully created individual fanwork dictionary for link 158
# Successfully appended individual fanwork dictionary 158 to all_candela_works_dict.
# Current fanwork link: 159 of 210
# Successfully loaded fanworks and created soup objects for link 159
# Successfully cleaned all_dd_stripped for link 159
# Successfully created individual fanwork dictionary for link 159
# Successfully appended individual fanwork dictionary 159 to all_candela_works_dict.
# Current fanwork link: 160 of 210
# Successfully loaded fanworks and created soup objects for link 160
# Successfully cleaned all_dd_stripped for link 160
# Successfully created individual fanwork dictionary for link 160
# Successfully appended individual fanwork dictionary 160 to all_candela_works_dict.
# Current fanwork link: 161 of 210
# Successfully loaded fanworks and created soup objects for link 161
# Successfully cleaned all_dd_stripped for link 161
# Successfully created individual fanwork dictionary for link 161
# Successfully appended individual fanwork dictionary 161 to all_candela_works_dict.
# Current fanwork link: 162 of 210
# Successfully loaded fanworks and created soup objects for link 162
# Successfully cleaned all_dd_stripped for link 162
# Successfully created individual fanwork dictionary for link 162
# Successfully appended individual fanwork dictionary 162 to all_candela_works_dict.
# Current fanwork link: 163 of 210
# Successfully loaded fanworks and created soup objects for link 163
# Successfully cleaned all_dd_stripped for link 163
# Successfully created individual fanwork dictionary for link 163
# Successfully appended individual fanwork dictionary 163 to all_candela_works_dict.
# Current fanwork link: 164 of 210
# Successfully loaded fanworks and created soup objects for link 164
# Successfully cleaned all_dd_stripped for link 164
# Successfully created individual fanwork dictionary for link 164
# Successfully appended individual fanwork dictionary 164 to all_candela_works_dict.
# Current fanwork link: 165 of 210
# Successfully loaded fanworks and created soup objects for link 165
# Successfully cleaned all_dd_stripped for link 165
# Successfully created individual fanwork dictionary for link 165
# Successfully appended individual fanwork dictionary 165 to all_candela_works_dict.
# Current fanwork link: 166 of 210
# Successfully loaded fanworks and created soup objects for link 166
# Successfully cleaned all_dd_stripped for link 166
# Successfully created individual fanwork dictionary for link 166
# Successfully appended individual fanwork dictionary 166 to all_candela_works_dict.
# Current fanwork link: 167 of 210
# Successfully loaded fanworks and created soup objects for link 167
# Successfully cleaned all_dd_stripped for link 167
# Successfully created individual fanwork dictionary for link 167
# Successfully appended individual fanwork dictionary 167 to all_candela_works_dict.
# Current fanwork link: 168 of 210
# Successfully loaded fanworks and created soup objects for link 168
# Successfully cleaned all_dd_stripped for link 168
# Successfully created individual fanwork dictionary for link 168
# Successfully appended individual fanwork dictionary 168 to all_candela_works_dict.
# Current fanwork link: 169 of 210
# Successfully loaded fanworks and created soup objects for link 169
# Successfully cleaned all_dd_stripped for link 169
# Successfully created individual fanwork dictionary for link 169
# Successfully appended individual fanwork dictionary 169 to all_candela_works_dict.
# Current fanwork link: 170 of 210
# Successfully loaded fanworks and created soup objects for link 170
# Successfully cleaned all_dd_stripped for link 170
# Successfully created individual fanwork dictionary for link 170
# Successfully appended individual fanwork dictionary 170 to all_candela_works_dict.
# Current fanwork link: 171 of 210
# Successfully loaded fanworks and created soup objects for link 171
# Successfully cleaned all_dd_stripped for link 171
# Successfully created individual fanwork dictionary for link 171
# Successfully appended individual fanwork dictionary 171 to all_candela_works_dict.
# Current fanwork link: 172 of 210
# Successfully loaded fanworks and created soup objects for link 172
# Successfully cleaned all_dd_stripped for link 172
# Successfully created individual fanwork dictionary for link 172
# Successfully appended individual fanwork dictionary 172 to all_candela_works_dict.
# Current fanwork link: 173 of 210
# Successfully loaded fanworks and created soup objects for link 173
# Successfully cleaned all_dd_stripped for link 173
# Successfully created individual fanwork dictionary for link 173
# Successfully appended individual fanwork dictionary 173 to all_candela_works_dict.
# Current fanwork link: 174 of 210
# Successfully loaded fanworks and created soup objects for link 174
# Successfully cleaned all_dd_stripped for link 174
# Successfully created individual fanwork dictionary for link 174
# Successfully appended individual fanwork dictionary 174 to all_candela_works_dict.
# Current fanwork link: 175 of 210
# Successfully loaded fanworks and created soup objects for link 175
# Successfully cleaned all_dd_stripped for link 175
# Successfully created individual fanwork dictionary for link 175
# Successfully appended individual fanwork dictionary 175 to all_candela_works_dict.
# Current fanwork link: 176 of 210
# Successfully loaded fanworks and created soup objects for link 176
# Successfully cleaned all_dd_stripped for link 176
# Successfully created individual fanwork dictionary for link 176
# Successfully appended individual fanwork dictionary 176 to all_candela_works_dict.
# Current fanwork link: 177 of 210
# Successfully loaded fanworks and created soup objects for link 177
# Successfully cleaned all_dd_stripped for link 177
# Successfully created individual fanwork dictionary for link 177
# Successfully appended individual fanwork dictionary 177 to all_candela_works_dict.
# Current fanwork link: 178 of 210
# Successfully loaded fanworks and created soup objects for link 178
# Successfully cleaned all_dd_stripped for link 178
# Successfully created individual fanwork dictionary for link 178
# Successfully appended individual fanwork dictionary 178 to all_candela_works_dict.
# Current fanwork link: 179 of 210
# Successfully loaded fanworks and created soup objects for link 179
# Successfully cleaned all_dd_stripped for link 179
# Successfully created individual fanwork dictionary for link 179
# Successfully appended individual fanwork dictionary 179 to all_candela_works_dict.
# Current fanwork link: 180 of 210
# Successfully loaded fanworks and created soup objects for link 180
# Successfully cleaned all_dd_stripped for link 180
# Successfully created individual fanwork dictionary for link 180
# Successfully appended individual fanwork dictionary 180 to all_candela_works_dict.
# Current fanwork link: 181 of 210
# Successfully loaded fanworks and created soup objects for link 181
# Successfully cleaned all_dd_stripped for link 181
# Successfully created individual fanwork dictionary for link 181
# Successfully appended individual fanwork dictionary 181 to all_candela_works_dict.
# Current fanwork link: 182 of 210
# Successfully loaded fanworks and created soup objects for link 182
# Successfully cleaned all_dd_stripped for link 182
# Successfully created individual fanwork dictionary for link 182
# Successfully appended individual fanwork dictionary 182 to all_candela_works_dict.
# Current fanwork link: 183 of 210
# Successfully loaded fanworks and created soup objects for link 183
# Successfully cleaned all_dd_stripped for link 183
# Successfully created individual fanwork dictionary for link 183
# Successfully appended individual fanwork dictionary 183 to all_candela_works_dict.
# Current fanwork link: 184 of 210
# Successfully loaded fanworks and created soup objects for link 184
# Successfully cleaned all_dd_stripped for link 184
# Successfully created individual fanwork dictionary for link 184
# Successfully appended individual fanwork dictionary 184 to all_candela_works_dict.
# Current fanwork link: 185 of 210
# Successfully loaded fanworks and created soup objects for link 185
# Successfully cleaned all_dd_stripped for link 185
# Successfully created individual fanwork dictionary for link 185
# Successfully appended individual fanwork dictionary 185 to all_candela_works_dict.
# Current fanwork link: 186 of 210
# Successfully loaded fanworks and created soup objects for link 186
# Successfully cleaned all_dd_stripped for link 186
# Successfully created individual fanwork dictionary for link 186
# Successfully appended individual fanwork dictionary 186 to all_candela_works_dict.
# Current fanwork link: 187 of 210
# Successfully loaded fanworks and created soup objects for link 187
# Successfully cleaned all_dd_stripped for link 187
# Successfully created individual fanwork dictionary for link 187
# Successfully appended individual fanwork dictionary 187 to all_candela_works_dict.
# Current fanwork link: 188 of 210
# Successfully loaded fanworks and created soup objects for link 188
# Successfully cleaned all_dd_stripped for link 188
# Successfully created individual fanwork dictionary for link 188
# Successfully appended individual fanwork dictionary 188 to all_candela_works_dict.
# Current fanwork link: 189 of 210
# Successfully loaded fanworks and created soup objects for link 189
# Successfully cleaned all_dd_stripped for link 189
# Successfully created individual fanwork dictionary for link 189
# Successfully appended individual fanwork dictionary 189 to all_candela_works_dict.
# Current fanwork link: 190 of 210
# Successfully loaded fanworks and created soup objects for link 190
# Successfully cleaned all_dd_stripped for link 190
# Successfully created individual fanwork dictionary for link 190
# Successfully appended individual fanwork dictionary 190 to all_candela_works_dict.
# Current fanwork link: 191 of 210
# Successfully loaded fanworks and created soup objects for link 191
# Successfully cleaned all_dd_stripped for link 191
# Successfully created individual fanwork dictionary for link 191
# Successfully appended individual fanwork dictionary 191 to all_candela_works_dict.
# Current fanwork link: 192 of 210
# Successfully loaded fanworks and created soup objects for link 192
# Successfully cleaned all_dd_stripped for link 192
# Successfully created individual fanwork dictionary for link 192
# Successfully appended individual fanwork dictionary 192 to all_candela_works_dict.
# Current fanwork link: 193 of 210
# Successfully loaded fanworks and created soup objects for link 193
# Successfully cleaned all_dd_stripped for link 193
# Successfully created individual fanwork dictionary for link 193
# Successfully appended individual fanwork dictionary 193 to all_candela_works_dict.
# Current fanwork link: 194 of 210
# Successfully loaded fanworks and created soup objects for link 194
# Successfully cleaned all_dd_stripped for link 194
# Successfully created individual fanwork dictionary for link 194
# Successfully appended individual fanwork dictionary 194 to all_candela_works_dict.
# Current fanwork link: 195 of 210
# Successfully loaded fanworks and created soup objects for link 195
# Successfully cleaned all_dd_stripped for link 195
# Successfully created individual fanwork dictionary for link 195
# Successfully appended individual fanwork dictionary 195 to all_candela_works_dict.
# Current fanwork link: 196 of 210
# Successfully loaded fanworks and created soup objects for link 196
# Successfully cleaned all_dd_stripped for link 196
# Successfully created individual fanwork dictionary for link 196
# Successfully appended individual fanwork dictionary 196 to all_candela_works_dict.
# Current fanwork link: 197 of 210
# Successfully loaded fanworks and created soup objects for link 197
# Successfully cleaned all_dd_stripped for link 197
# Successfully created individual fanwork dictionary for link 197
# Successfully appended individual fanwork dictionary 197 to all_candela_works_dict.
# Current fanwork link: 198 of 210
# Successfully loaded fanworks and created soup objects for link 198
# Successfully cleaned all_dd_stripped for link 198
# Successfully created individual fanwork dictionary for link 198
# Successfully appended individual fanwork dictionary 198 to all_candela_works_dict.
# Current fanwork link: 199 of 210
# Successfully loaded fanworks and created soup objects for link 199
# Successfully cleaned all_dd_stripped for link 199
# Successfully created individual fanwork dictionary for link 199
# Successfully appended individual fanwork dictionary 199 to all_candela_works_dict.
# Current fanwork link: 200 of 210
# Successfully loaded fanworks and created soup objects for link 200
# Successfully cleaned all_dd_stripped for link 200
# Successfully created individual fanwork dictionary for link 200
# Successfully appended individual fanwork dictionary 200 to all_candela_works_dict.
# Current fanwork link: 201 of 210
# Successfully loaded fanworks and created soup objects for link 201
# Successfully cleaned all_dd_stripped for link 201
# Successfully created individual fanwork dictionary for link 201
# Successfully appended individual fanwork dictionary 201 to all_candela_works_dict.
# Current fanwork link: 202 of 210
# Successfully loaded fanworks and created soup objects for link 202
# Successfully cleaned all_dd_stripped for link 202
# Successfully created individual fanwork dictionary for link 202
# Successfully appended individual fanwork dictionary 202 to all_candela_works_dict.
# Current fanwork link: 203 of 210
# Successfully loaded fanworks and created soup objects for link 203
# Successfully cleaned all_dd_stripped for link 203
# Successfully created individual fanwork dictionary for link 203
# Successfully appended individual fanwork dictionary 203 to all_candela_works_dict.
# Current fanwork link: 204 of 210
# Successfully loaded fanworks and created soup objects for link 204
# Successfully cleaned all_dd_stripped for link 204
# Successfully created individual fanwork dictionary for link 204
# Successfully appended individual fanwork dictionary 204 to all_candela_works_dict.
# Current fanwork link: 205 of 210
# Successfully loaded fanworks and created soup objects for link 205
# Successfully cleaned all_dd_stripped for link 205
# Successfully created individual fanwork dictionary for link 205
# Successfully appended individual fanwork dictionary 205 to all_candela_works_dict.
# Current fanwork link: 206 of 210
# Successfully loaded fanworks and created soup objects for link 206
# Successfully cleaned all_dd_stripped for link 206
# Successfully created individual fanwork dictionary for link 206
# Successfully appended individual fanwork dictionary 206 to all_candela_works_dict.
# Current fanwork link: 207 of 210
# Successfully loaded fanworks and created soup objects for link 207
# Successfully cleaned all_dd_stripped for link 207
# Successfully created individual fanwork dictionary for link 207
# Successfully appended individual fanwork dictionary 207 to all_candela_works_dict.
# Current fanwork link: 208 of 210
# Successfully loaded fanworks and created soup objects for link 208
# Successfully cleaned all_dd_stripped for link 208
# Successfully created individual fanwork dictionary for link 208
# Successfully appended individual fanwork dictionary 208 to all_candela_works_dict.
# Current fanwork link: 209 of 210
# Successfully loaded fanworks and created soup objects for link 209
# Successfully cleaned all_dd_stripped for link 209
# Successfully created individual fanwork dictionary for link 209
# Successfully appended individual fanwork dictionary 209 to all_candela_works_dict.
# Current fanwork link: 210 of 210
# Successfully loaded fanworks and created soup objects for link 210
# Successfully cleaned all_dd_stripped for link 210
# Successfully created individual fanwork dictionary for link 210
# Successfully appended individual fanwork dictionary 210 to all_candela_works_dict.

# %%
print(len(all_candela_works_dict))
# Out:
# 210

# %%
## convert to json and save to file
all_candela_works_json = convert_to_json(all_candela_works_dict)
with open('../../data/allcandelaworks.json', "w") as f:
    f.write(all_candela_works_json)

# %% [markdown]
# ## Full fanworks - from individual pagination links

# %%
def get_links_to_scrape(filepath):
    """Takes in a txt file of pagination links and returns a list."""
    links_to_scrape = open(filepath).readlines()
    return links_to_scrape

# %%
# test get_links_to_scrape
links_to_scrape = get_links_to_scrape('./data/txt_files.txt')
print(links_to_scrape)
# Out:
# ['https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=1\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=2\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=3\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=4\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=5\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=6\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=7\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=8\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=9\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=10\n', 'https://archiveofourown.org/tags/Candela%20Obscura%20(Critical%20Role%20Web%20Series)/works?view_adult=true&page=11']

# %%
## get pagination links to scrape
pagination_links1 = get_fanwork_links('./data/txt_files/fanwork_links1.txt')
pagination_links2 = get_fanwork_links('./data/txt_files/fanwork_links2.txt')
pagination_links3 = get_fanwork_links('./data/txt_files/fanwork_links3.txt')
pagination_links4 = get_fanwork_links('./data/txt_files/fanwork_links4.txt')
pagination_links5 = get_fanwork_links('./data/txt_files/fanwork_links5.txt')
pagination_links6 = get_fanwork_links('./data/txt_files/fanwork_links6.txt')
pagination_links7 = get_fanwork_links('./data/txt_files/fanwork_links7.txt')
pagination_links8 = get_fanwork_links('./data/txt_files/fanwork_links8.txt')
pagination_links9 = get_fanwork_links('./data/txt_files/fanwork_links9.txt')
pagination_links10 = get_fanwork_links('./data/txt_files/fanwork_links10.txt')
pagination_links11 = get_fanwork_links('./data/txt_files/fanwork_links11.txt')

# %%
print(pagination_links1)
print(len(pagination_links1))
# Out:
# ['https://archiveofourown.org/works/80602681', 'https://archiveofourown.org/works/80602681/chapters/223632446', 'https://archiveofourown.org/works/51518734', 'https://archiveofourown.org/works/51518734/chapters/220941681', 'https://archiveofourown.org/works/51010177', 'https://archiveofourown.org/works/51010177/chapters/212450026', 'https://archiveofourown.org/works/80156821', 'https://archiveofourown.org/works/74479381', 'https://archiveofourown.org/works/74479381/chapters/203838821', 'https://archiveofourown.org/works/56574286', 'https://archiveofourown.org/works/56574286/chapters/202821756', 'https://archiveofourown.org/works/75864761', 'https://archiveofourown.org/works/73925776', 'https://archiveofourown.org/works/69525656', 'https://archiveofourown.org/works/69696606', 'https://archiveofourown.org/works/69266581', 'https://archiveofourown.org/works/68678736', 'https://archiveofourown.org/works/59798779', 'https://archiveofourown.org/works/59798779/chapters/174878791', 'https://archiveofourown.org/works/55118308', 'https://archiveofourown.org/works/55118308/chapters/139992697', 'https://archiveofourown.org/works/66001534', 'https://archiveofourown.org/works/62477026', 'https://archiveofourown.org/works/62036794', 'https://archiveofourown.org/works/60847894', 'https://archiveofourown.org/works/51300544', 'https://archiveofourown.org/works/51300544/chapters/152323312', 'https://archiveofourown.org/works/56817901', 'https://archiveofourown.org/works/56817901/chapters/150901159']
# 29

# %%
pagination_links = [pagination_links1, pagination_links2, pagination_links3, pagination_links4, pagination_links5, pagination_links6, pagination_links7, pagination_links8, pagination_links9, pagination_links10, pagination_links11]

# %%
print(len(pagination_links))
print(pagination_links)
# Out:
# 11
# [['https://archiveofourown.org/works/80602681', 'https://archiveofourown.org/works/80602681/chapters/223632446', 'https://archiveofourown.org/works/51518734', 'https://archiveofourown.org/works/51518734/chapters/220941681', 'https://archiveofourown.org/works/51010177', 'https://archiveofourown.org/works/51010177/chapters/212450026', 'https://archiveofourown.org/works/80156821', 'https://archiveofourown.org/works/74479381', 'https://archiveofourown.org/works/74479381/chapters/203838821', 'https://archiveofourown.org/works/56574286', 'https://archiveofourown.org/works/56574286/chapters/202821756', 'https://archiveofourown.org/works/75864761', 'https://archiveofourown.org/works/73925776', 'https://archiveofourown.org/works/69525656', 'https://archiveofourown.org/works/69696606', 'https://archiveofourown.org/works/69266581', 'https://archiveofourown.org/works/68678736', 'https://archiveofourown.org/works/59798779', 'https://archiveofourown.org/works/59798779/chapters/174878791', 'https://archiveofourown.org/works/55118308', 'https://archiveofourown.org/works/55118308/chapters/139992697', 'https://archiveofourown.org/works/66001534', 'https://archiveofourown.org/works/62477026', 'https://archiveofourown.org/works/62036794', 'https://archiveofourown.org/works/60847894', 'https://archiveofourown.org/works/51300544', 'https://archiveofourown.org/works/51300544/chapters/152323312', 'https://archiveofourown.org/works/56817901', 'https://archiveofourown.org/works/56817901/chapters/150901159'], ['https://archiveofourown.org/works/56876515', 'https://archiveofourown.org/works/56876515/chapters/150396562', 'https://archiveofourown.org/works/58577140', 'https://archiveofourown.org/works/58428907', 'https://archiveofourown.org/works/58397821', 'https://archiveofourown.org/works/58377157', 'https://archiveofourown.org/works/58377157/chapters/148685752', 'https://archiveofourown.org/works/55745599', 'https://archiveofourown.org/works/55745599/chapters/146914660', 'https://archiveofourown.org/works/57514030', 'https://archiveofourown.org/works/57373072', 'https://archiveofourown.org/works/57148285', 'https://archiveofourown.org/works/57049183', 'https://archiveofourown.org/works/57168277', 'https://archiveofourown.org/works/57168277/chapters/145408120', 'https://archiveofourown.org/works/56944855', 'https://archiveofourown.org/works/56887570', 'https://archiveofourown.org/works/56832094', 'https://archiveofourown.org/works/56748733', 'https://archiveofourown.org/works/56530477', 'https://archiveofourown.org/works/56410426', 'https://archiveofourown.org/works/56396950', 'https://archiveofourown.org/works/56370673', 'https://archiveofourown.org/works/56348689'], ['https://archiveofourown.org/works/56112163', 'https://archiveofourown.org/works/56104648', 'https://archiveofourown.org/works/55897618', 'https://archiveofourown.org/works/55858051', 'https://archiveofourown.org/works/55849537', 'https://archiveofourown.org/works/55829683', 'https://archiveofourown.org/works/55821961', 'https://archiveofourown.org/works/55602580', 'https://archiveofourown.org/works/55469746', 'https://archiveofourown.org/works/55469746/chapters/141333463', 'https://archiveofourown.org/works/55495195', 'https://archiveofourown.org/works/55447729', 'https://archiveofourown.org/works/55024471', 'https://archiveofourown.org/works/55024471/chapters/140673469', 'https://archiveofourown.org/works/54959626', 'https://archiveofourown.org/works/54959626/chapters/140671291', 'https://archiveofourown.org/works/55205539', 'https://archiveofourown.org/works/55188448', 'https://archiveofourown.org/works/55022362', 'https://archiveofourown.org/works/54638023', 'https://archiveofourown.org/works/54638023/chapters/139400986', 'https://archiveofourown.org/works/54777958', 'https://archiveofourown.org/works/54682489', 'https://archiveofourown.org/works/53537782', 'https://archiveofourown.org/works/53537782/chapters/137778904'], ['https://archiveofourown.org/works/54270886', 'https://archive ...

# %%
def remove_chapter_links(work_links):
    """Takes in a list of pared down fanwork URLs from pare_down_work_links and removes any links to individual fanwork chapters."""
    works_only_final = work_links
    for i in range(len(work_links)):
        current_link = work_links[i]
        if 'chapters' in current_link:
            works_only_final.remove(current_link)
        else:
            continue
    return works_only_final

# %%
# remove chapters links from each pagination link
for i in range(len(pagination_links1)):
    current_link = pagination_links1[i]
    if 'chapters' in current_link:
        pagination_links1.remove(current_link)
    else:
        continue

# %%
print(pagination_links1)
print(len(pagination_links1))
# Out:
# ['https://archiveofourown.org/works/80602681', 'https://archiveofourown.org/works/51518734', 'https://archiveofourown.org/works/51010177', 'https://archiveofourown.org/works/80156821', 'https://archiveofourown.org/works/74479381', 'https://archiveofourown.org/works/56574286', 'https://archiveofourown.org/works/75864761', 'https://archiveofourown.org/works/73925776', 'https://archiveofourown.org/works/69525656', 'https://archiveofourown.org/works/69696606', 'https://archiveofourown.org/works/69266581', 'https://archiveofourown.org/works/68678736', 'https://archiveofourown.org/works/59798779', 'https://archiveofourown.org/works/55118308', 'https://archiveofourown.org/works/66001534', 'https://archiveofourown.org/works/62477026', 'https://archiveofourown.org/works/62036794', 'https://archiveofourown.org/works/60847894', 'https://archiveofourown.org/works/51300544', 'https://archiveofourown.org/works/56817901']
# 20

# %%
print(len(pagination_links))
# Out:
# 11

# %%
## individual pagination links list

all_candela_works_dict1 = {}

for i in range(len(pagination_links)):
    total_fanworks = len(pagination_links[i])
    current_dict = {}
    current_pagination_link = pagination_links[i]
    print("Current pagination link: " + str(i+1) + " of", str(len(pagination_links)))
    for index in range(len(current_pagination_link)):
        print("Current fanwork link: " + str(index+1), " of", total_fanworks)

        ## load fanworks and create soup objects
        soup = get_html_doc_fanworks(fanwork_links[index])
        all_dt = get_all_dt(soup)
        all_dt_updated = update_all_dt(all_dt)
        # print(all_dt_updated)
        all_dd = get_all_dd(soup)
        print("Successfully loaded fanworks and created soup objects for link", str(index+1))

        ## clean up all_dd
        all_dd_stripped = strip_dd(all_dd)
        # print(len(all_dd_stripped))
        all_dd_stripped = cleanup_fandom_tags(all_dd_stripped)
        all_dd_stripped = cleanup_relationship_tags(all_dd_stripped)
        all_dd_stripped = cleanup_character_tags(all_dd_stripped)
        all_dd_stripped = cleanup_additional_tags(all_dd_stripped)
        print("Successfully cleaned all_dd_stripped for link", str(index+1))

        ## create individual fanwork dictionary
        fanwork_dict = create_fanwork_dict(all_dt_updated, all_dd_stripped)
        # print(fanwork_dict)
        print("Successfully created individual fanwork dictionary for link", str(index+1))

        ## append fanwork dictionary to current dictionary
        append_all_works_dict(fanwork_dict, current_dict)
        print("Successfully appended individual fanwork dictionary", str(index+1), "to current dict.")

    ## convert current dict to json and save to file
    current_json = convert_to_json(current_dict)
    json_filepath = './data/json_files/candela_page' + str(i+1) + '.json'
    with open(json_filepath, "w") as f:
        f.write(current_json)

# what am I trying to do here
# I'm trying to save each json file with a new name so they don't overwrite
# Out:
# Current pagination link: 1 of 11
# Current fanwork link: 1  of 20
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 20
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 20
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 20
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 20
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 20
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 20
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 20
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 20
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 20
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 20
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 20
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 20
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 20
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 20
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 20
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 20
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 20
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 20
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 20
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current pagination link: 2 of 11
# Current fanwork link: 1  of 20
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 20
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 20
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 20
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 20
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 20
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 20
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 20
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 20
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 20
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 20
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 20
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 20
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 20
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 20
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 20
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 20
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 20
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 20
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 20
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current pagination link: 3 of 11
# Current fanwork link: 1  of 25
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 25
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 25
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 25
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 25
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 25
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 25
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 25
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 25
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 25
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 25
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 25
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 25
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 25
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 25
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 25
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 25
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 25
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 25
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 25
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current fanwork link: 21  of 25
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to current dict.
# Current fanwork link: 22  of 25
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to current dict.
# Current fanwork link: 23  of 25
# Successfully loaded fanworks and created soup objects for link 23
# Successfully cleaned all_dd_stripped for link 23
# Successfully created individual fanwork dictionary for link 23
# Successfully appended individual fanwork dictionary 23 to current dict.
# Current fanwork link: 24  of 25
# Successfully loaded fanworks and created soup objects for link 24
# Successfully cleaned all_dd_stripped for link 24
# Successfully created individual fanwork dictionary for link 24
# Successfully appended individual fanwork dictionary 24 to current dict.
# Current fanwork link: 25  of 25
# Successfully loaded fanworks and created soup objects for link 25
# Successfully cleaned all_dd_stripped for link 25
# Successfully created individual fanwork dictionary for link 25
# Successfully appended individual fanwork dictionary 25 to current dict.
# Current pagination link: 4 of 11
# Current fanwork link: 1  of 23
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 23
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 23
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 23
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 23
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 23
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 23
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 23
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 23
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 23
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 23
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 23
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 23
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 23
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 23
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 23
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 23
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 23
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 23
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 23
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current fanwork link: 21  of 23
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to current dict.
# Current fanwork link: 22  of 23
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to current dict.
# Current fanwork link: 23  of 23
# Successfully loaded fanworks and created soup objects for link 23
# Successfully cleaned all_dd_stripped for link 23
# Successfully created individual fanwork dictionary for link 23
# Successfully appended individual fanwork dictionary 23 to current dict.
# Current pagination link: 5 of 11
# Current fanwork link: 1  of 23
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 23
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 23
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 23
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 23
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 23
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 23
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 23
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 23
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 23
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 23
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 23
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 23
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 23
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 23
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 23
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 23
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 23
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 23
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 23
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current fanwork link: 21  of 23
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to current dict.
# Current fanwork link: 22  of 23
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to current dict.
# Current fanwork link: 23  of 23
# Successfully loaded fanworks and created soup objects for link 23
# Successfully cleaned all_dd_stripped for link 23
# Successfully created individual fanwork dictionary for link 23
# Successfully appended individual fanwork dictionary 23 to current dict.
# Current pagination link: 6 of 11
# Current pagination link: 7 of 11
# Current fanwork link: 1  of 24
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 24
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 24
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 24
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 24
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 24
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 24
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 24
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 24
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 24
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 24
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 24
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 24
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 24
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 24
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 24
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 24
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 24
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 24
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 24
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current fanwork link: 21  of 24
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to current dict.
# Current fanwork link: 22  of 24
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to current dict.
# Current fanwork link: 23  of 24
# Successfully loaded fanworks and created soup objects for link 23
# Successfully cleaned all_dd_stripped for link 23
# Successfully created individual fanwork dictionary for link 23
# Successfully appended individual fanwork dictionary 23 to current dict.
# Current fanwork link: 24  of 24
# Successfully loaded fanworks and created soup objects for link 24
# Successfully cleaned all_dd_stripped for link 24
# Successfully created individual fanwork dictionary for link 24
# Successfully appended individual fanwork dictionary 24 to current dict.
# Current pagination link: 8 of 11
# Current fanwork link: 1  of 22
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 22
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 22
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 22
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 22
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 22
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 22
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 22
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 22
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 22
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 22
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 22
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 22
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 22
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 22
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 22
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 22
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 22
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 22
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 22
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current fanwork link: 21  of 22
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to current dict.
# Current fanwork link: 22  of 22
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to current dict.
# Current pagination link: 9 of 11
# Current fanwork link: 1  of 23
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 23
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 23
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 23
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 23
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 23
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 23
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 23
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 23
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 23
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 23
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 23
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 23
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 23
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 23
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 23
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 23
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 23
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 23
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 23
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current fanwork link: 21  of 23
# Successfully loaded fanworks and created soup objects for link 21
# Successfully cleaned all_dd_stripped for link 21
# Successfully created individual fanwork dictionary for link 21
# Successfully appended individual fanwork dictionary 21 to current dict.
# Current fanwork link: 22  of 23
# Successfully loaded fanworks and created soup objects for link 22
# Successfully cleaned all_dd_stripped for link 22
# Successfully created individual fanwork dictionary for link 22
# Successfully appended individual fanwork dictionary 22 to current dict.
# Current fanwork link: 23  of 23
# Successfully loaded fanworks and created soup objects for link 23
# Successfully cleaned all_dd_stripped for link 23
# Successfully created individual fanwork dictionary for link 23
# Successfully appended individual fanwork dictionary 23 to current dict.
# Current pagination link: 10 of 11
# Current fanwork link: 1  of 20
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 20
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 20
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 20
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 20
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 20
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 20
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 20
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 20
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 20
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 20
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 20
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.
# Current fanwork link: 13  of 20
# Successfully loaded fanworks and created soup objects for link 13
# Successfully cleaned all_dd_stripped for link 13
# Successfully created individual fanwork dictionary for link 13
# Successfully appended individual fanwork dictionary 13 to current dict.
# Current fanwork link: 14  of 20
# Successfully loaded fanworks and created soup objects for link 14
# Successfully cleaned all_dd_stripped for link 14
# Successfully created individual fanwork dictionary for link 14
# Successfully appended individual fanwork dictionary 14 to current dict.
# Current fanwork link: 15  of 20
# Successfully loaded fanworks and created soup objects for link 15
# Successfully cleaned all_dd_stripped for link 15
# Successfully created individual fanwork dictionary for link 15
# Successfully appended individual fanwork dictionary 15 to current dict.
# Current fanwork link: 16  of 20
# Successfully loaded fanworks and created soup objects for link 16
# Successfully cleaned all_dd_stripped for link 16
# Successfully created individual fanwork dictionary for link 16
# Successfully appended individual fanwork dictionary 16 to current dict.
# Current fanwork link: 17  of 20
# Successfully loaded fanworks and created soup objects for link 17
# Successfully cleaned all_dd_stripped for link 17
# Successfully created individual fanwork dictionary for link 17
# Successfully appended individual fanwork dictionary 17 to current dict.
# Current fanwork link: 18  of 20
# Successfully loaded fanworks and created soup objects for link 18
# Successfully cleaned all_dd_stripped for link 18
# Successfully created individual fanwork dictionary for link 18
# Successfully appended individual fanwork dictionary 18 to current dict.
# Current fanwork link: 19  of 20
# Successfully loaded fanworks and created soup objects for link 19
# Successfully cleaned all_dd_stripped for link 19
# Successfully created individual fanwork dictionary for link 19
# Successfully appended individual fanwork dictionary 19 to current dict.
# Current fanwork link: 20  of 20
# Successfully loaded fanworks and created soup objects for link 20
# Successfully cleaned all_dd_stripped for link 20
# Successfully created individual fanwork dictionary for link 20
# Successfully appended individual fanwork dictionary 20 to current dict.
# Current pagination link: 11 of 11
# Current fanwork link: 1  of 12
# Successfully loaded fanworks and created soup objects for link 1
# Successfully cleaned all_dd_stripped for link 1
# Successfully created individual fanwork dictionary for link 1
# Successfully appended individual fanwork dictionary 1 to current dict.
# Current fanwork link: 2  of 12
# Successfully loaded fanworks and created soup objects for link 2
# Successfully cleaned all_dd_stripped for link 2
# Successfully created individual fanwork dictionary for link 2
# Successfully appended individual fanwork dictionary 2 to current dict.
# Current fanwork link: 3  of 12
# Successfully loaded fanworks and created soup objects for link 3
# Successfully cleaned all_dd_stripped for link 3
# Successfully created individual fanwork dictionary for link 3
# Successfully appended individual fanwork dictionary 3 to current dict.
# Current fanwork link: 4  of 12
# Successfully loaded fanworks and created soup objects for link 4
# Successfully cleaned all_dd_stripped for link 4
# Successfully created individual fanwork dictionary for link 4
# Successfully appended individual fanwork dictionary 4 to current dict.
# Current fanwork link: 5  of 12
# Successfully loaded fanworks and created soup objects for link 5
# Successfully cleaned all_dd_stripped for link 5
# Successfully created individual fanwork dictionary for link 5
# Successfully appended individual fanwork dictionary 5 to current dict.
# Current fanwork link: 6  of 12
# Successfully loaded fanworks and created soup objects for link 6
# Successfully cleaned all_dd_stripped for link 6
# Successfully created individual fanwork dictionary for link 6
# Successfully appended individual fanwork dictionary 6 to current dict.
# Current fanwork link: 7  of 12
# Successfully loaded fanworks and created soup objects for link 7
# Successfully cleaned all_dd_stripped for link 7
# Successfully created individual fanwork dictionary for link 7
# Successfully appended individual fanwork dictionary 7 to current dict.
# Current fanwork link: 8  of 12
# Successfully loaded fanworks and created soup objects for link 8
# Successfully cleaned all_dd_stripped for link 8
# Successfully created individual fanwork dictionary for link 8
# Successfully appended individual fanwork dictionary 8 to current dict.
# Current fanwork link: 9  of 12
# Successfully loaded fanworks and created soup objects for link 9
# Successfully cleaned all_dd_stripped for link 9
# Successfully created individual fanwork dictionary for link 9
# Successfully appended individual fanwork dictionary 9 to current dict.
# Current fanwork link: 10  of 12
# Successfully loaded fanworks and created soup objects for link 10
# Successfully cleaned all_dd_stripped for link 10
# Successfully created individual fanwork dictionary for link 10
# Successfully appended individual fanwork dictionary 10 to current dict.
# Current fanwork link: 11  of 12
# Successfully loaded fanworks and created soup objects for link 11
# Successfully cleaned all_dd_stripped for link 11
# Successfully created individual fanwork dictionary for link 11
# Successfully appended individual fanwork dictionary 11 to current dict.
# Current fanwork link: 12  of 12
# Successfully loaded fanworks and created soup objects for link 12
# Successfully cleaned all_dd_stripped for link 12
# Successfully created individual fanwork dictionary for link 12
# Successfully appended individual fanwork dictionary 12 to current dict.

# %%
# code from: https://www.geeksforgeeks.org/python/how-to-merge-multiple-json-files-using-python/
def merge_json_files(file_paths, output_file):
    merged_data = []
    for path in file_paths:
        with open(path, 'r') as file:
            data = json.load(file)
            merged_data.append(data)
    with open(output_file, 'w') as outfile:
        json.dump(merged_data, outfile)

# %%
# append individual jsons to all_candela_works_dict1
file_paths = ["data/json_files/candela_page1.json",
              "data/json_files/candela_page2.json",
              "data/json_files/candela_page3.json",
              "data/json_files/candela_page4.json",
              "data/json_files/candela_page5.json",
              "data/json_files/candela_page6.json",
              "data/json_files/candela_page7.json",
              "data/json_files/candela_page8.json",
              "data/json_files/candela_page9.json",
              "data/json_files/candela_page10.json",
              "data/json_files/candela_page11.json",
              ]

# create new JSON file
output_dict = {}
output_file = convert_to_json(output_dict)
output_filepath = "./data/json_files/candela_merged.json"
with open(output_filepath, 'w') as f:
    f.write(output_file)

merge_json_files(file_paths, output_filepath)
print(f"Merged data written to '{output_file}'")
# Out:
# Merged data written to '{}'

# %%
print(len(all_candela_works_dict1))

# %%
## convert to json and save to file
all_candela_works_json1 = convert_to_json(all_candela_works_dict1)
with open('./data/allcandelaworks.json', "w") as f:
    f.write(all_candela_works_json1)

# %% [markdown]
# # Testing / Troubleshooting

# %% [markdown]
# ## Round 1

# %%
def check_if_rating(all_dt):
    if 'Rating' in all_dt_updated:
        print('Rating is in all_dt_updated')
    else:
        print("nope")

# %%
for i in range(len(fanwork_links)):
    fanwork_links[i] = fanwork_links[i].replace("\n","")

# %%
test_fanwork_list = fanwork_links[0:10]
print(test_fanwork_list)

# %%
print(test_fanwork_list[0])

# %%
def check_word_count(all_dt):
    if 'Word Count' in all_dt:
        print('Word Count is in all_dt')
    else:
        print("Word count is not in all_dt")

# %%
# create + fill all_works_dict
total_fanworks = len(test_fanwork_list)
all_works_dict2 = {}
for i in range(len(test_fanwork_list)):
    print("Current fanwork link:", str(i+1), "of", total_fanworks)

    ## load fanworks and create soup objects
    soup = get_html_doc_fanworks(test_fanwork_list[i])
    all_dt = get_all_dt(soup)
    all_dt_updated = update_all_dt(all_dt)
    check_if_rating(all_dt_updated)
    check_word_count(all_dt_updated)
    all_dd = get_all_dd(soup)
    print("Successfully loaded fanworks and created soup objects for link", str(i+1))

    ## clean up all_dd
    text_to_strip = ['<dd>','</dd>','<ul class="commas">','/ul>','\n',' ','<li>','</li>','><aclass="tag"href="','<ddclass=','</a><']
    all_dd_stripped = strip_dd(all_dd, text_to_strip)
    dd_list1 = cleanup_rating(all_dd_stripped)
    dd_list2 = cleanup_warnings(dd_list1)
    dd_list3 = cleanup_categories(dd_list2)
    dd_list4 = multiple_tags_to_lists(dd_list3)
    indices = get_idx_multiple_tags(dd_list4)
    dd_list5 = cleanup_multiple_tags(dd_list4, indices)
    print("Successfully cleaned all_dd for link", str(i+1))

    ## create individual fanwork dictionary
    fanwork_dict = create_fanwork_dict(all_dt_updated, dd_list5)
    print("Successfully created individual fanwork dictionary for link", str(i+1))

    ## append fanwork dictionary to all_works_dict1
    append_all_works_dict(fanwork_dict, all_works_dict2)
    print("Successfully appended individual fanwork dictionary", str(i+1), "to all_works_dict2.")

# %%
## convert to json and save to file
# convert to json
test_candela_works_json = convert_to_json(all_works_dict2)

# save json to file
with open('../../data/test_candela_works.json', "w") as f:
    f.write(test_candela_works_json)

# %% [markdown]
# ## Round 2

# %%
test_fanwork_list1 = fanwork_links[0:1]
print(test_fanwork_list1)
print(type(test_fanwork_list1))

# %%
# create + fill all_works_dict
total_fanworks = len(test_fanwork_list1)
all_works_dict3 = {}
for i in range(len(test_fanwork_list1)):
    print("Current fanwork link:", str(i+1), "of", total_fanworks)

    ## load fanworks and create soup objects
    soup = get_html_doc_fanworks(test_fanwork_list1[i])
    all_dt = get_all_dt(soup)
    all_dt_updated = update_all_dt(all_dt)
    check_if_rating(all_dt_updated)
    print(all_dt_updated[2])
    print(type(all_dt_updated[2]))
    all_dd = get_all_dd(soup)
    print("Successfully loaded fanworks and created soup objects for link", str(i+1))

    ## clean up all_dd
    text_to_strip = ['<dd>','</dd>','<ul class="commas">','/ul>','\n',' ','<li>','</li>','><aclass="tag"href="','<ddclass=','</a><']
    all_dd_stripped = strip_dd(all_dd, text_to_strip)
    dd_list1 = cleanup_rating(all_dd_stripped)
    dd_list2 = cleanup_warnings(dd_list1)
    dd_list3 = cleanup_categories(dd_list2)
    dd_list4 = multiple_tags_to_lists(dd_list3)
    indices = get_idx_multiple_tags(dd_list4)
    dd_list5 = cleanup_multiple_tags(dd_list4, indices)
    print("Successfully cleaned all_dd for link", str(i+1))

    ## create individual fanwork dictionary
    fanwork_dict = create_fanwork_dict(all_dt_updated, dd_list5)
    print(fanwork_dict)
    print("Successfully created individual fanwork dictionary for link", str(i+1))

    ## append fanwork dictionary to all_works_dict3
    append_all_works_dict(fanwork_dict, all_works_dict3)
    print("Successfully appended individual fanwork dictionary", str(i+1), "to all_works_dict3.")

# %%
## convert to json and save to file
# convert to json
test_candela_works_json1 = convert_to_json(all_works_dict3)

# save json to file
with open('../../data/test_candela_works1.json', "w") as f:
    f.write(test_candela_works_json1)

# %% [markdown]
# ## Round 3

# %%
test_fanwork_list2 = fanwork_links[1:2]
print(test_fanwork_list2)

# %%
a = [10, 20, 30, 40, 50]

if 30 in a:
    print("Element exists in the list")
else:
    print("Element does not exist")

# %%
# create + fill all_works_dict4
total_fanworks = len(test_fanwork_list2)
all_works_dict4 = {}
for i in range(len(test_fanwork_list2)):
    print("Current fanwork link:", str(i+1), "of", total_fanworks)

    ## load fanworks and create soup objects
    soup = get_html_doc_fanworks(test_fanwork_list2[i])
    all_dt = get_all_dt(soup)
    all_dt_updated = update_all_dt(all_dt)
    check_if_rating(all_dt_updated)
    all_dd = get_all_dd(soup)
    print("Successfully loaded fanworks and created soup objects for link", str(i+1))

    ## clean up all_dd
    text_to_strip = ['<dd>','</dd>','<ul class="commas">','/ul>','\n',' ','<li>','</li>','><aclass="tag"href="','<ddclass=','</a><']
    all_dd_stripped = strip_dd(all_dd, text_to_strip)
    dd_list1 = cleanup_rating(all_dd_stripped)
    dd_list2 = cleanup_warnings(dd_list1)
    dd_list3 = cleanup_categories(dd_list2)
    dd_list4 = multiple_tags_to_lists(dd_list3)
    indices = get_idx_multiple_tags(dd_list4)
    dd_list5 = cleanup_multiple_tags(dd_list4, indices)
    print("Successfully cleaned all_dd for link", str(i+1))

    ## create individual fanwork dictionary
    fanwork_dict = create_fanwork_dict(all_dt_updated, dd_list5)
    print("Successfully created individual fanwork dictionary for link", str(i+1))

    ## append fanwork dictionary to all_works_dict4
    append_all_works_dict(fanwork_dict, all_works_dict4)
    print("Successfully appended individual fanwork dictionary", str(i+1), "to all_works_dict4.")

# %%
## convert to json and save to file
# convert to json
test_candela_works_json2 = convert_to_json(all_works_dict4)

# save json to file
with open('../../data/test_candela_works2.json', "w") as f:
    f.write(test_candela_works_json2)
